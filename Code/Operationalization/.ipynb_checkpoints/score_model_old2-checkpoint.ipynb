# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from fbprophet import Prophet
from sklearn.metrics import mean_squared_error, mean_absolute_error
plt.style.use('fivethirtyeight') # For plots


# %store -r WORKDIR

if 'WORKDIR' not in dir():
    WORKDIR = 'C:/Users/thewr/git/mit_data_science.git/'




baseurl = 'https://thevirustracker.com/timeline/map-data.json'

countrycode = 'BR'

time_col = 'Datetime'

max_forecast_date = '01-Jun-2017'

data_proc_file = WORKDIR + '/Data/Processed/energy_consumption_data_modeling.parquet'
model_score_file = WORKDIR + '/Data/Modeling/model_scores.parquet'
model_file = WORKDIR + '/Data/Modeling/trained_models.jbl'

# %% [markdown]
# # Carrega Modelos

# %%
with open(model_file, 'rb') as fid:
    trained_models = pickle.load(fid)

#trained_models.keys()

# %%
#trained_models['BR']

# %% [markdown]
# # Carrega Tabela de Resultado da Modelagem

# %%
df_models = pd.read_parquet(model_score_file) 
df_models.head()
# Out:
#   model_name          date_begin            date_end     score
# 0    prophet 2002-01-01 01:00:00 2016-12-30 23:00:00  9.513801

# %% [markdown]
# # Carrega Dados Atualizados

# %%
#data_proc_file = WORKDIR + '/Data/Processed/energy_consumption_data_modeling.parquet'
data = pd.read_parquet(data_proc_file)

# %%
data.head()
# Out:
#              Datetime  PJME_MW
# 0 2002-01-01 01:00:00  30393.0
# 1 2002-01-01 02:00:00  29265.0
# 2 2002-01-01 03:00:00  28357.0
# 3 2002-01-01 04:00:00  27899.0
# 4 2002-01-01 05:00:00  28057.0

# %%
data.reset_index(drop=True, inplace=True)

# %%
data.head()
# Out:
#              Datetime  PJME_MW
# 0 2002-01-01 01:00:00  30393.0
# 1 2002-01-01 02:00:00  29265.0
# 2 2002-01-01 03:00:00  28357.0
# 3 2002-01-01 04:00:00  27899.0
# 4 2002-01-01 05:00:00  28057.0

# %%
data.set_index('Datetime', inplace=True)

# %%
data.head()
# Out:
#                      PJME_MW
# Datetime
# 2002-01-01 01:00:00  30393.0
# 2002-01-01 02:00:00  29265.0
# 2002-01-01 03:00:00  28357.0
# 2002-01-01 04:00:00  27899.0
# 2002-01-01 05:00:00  28057.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 145366 entries, 2002-01-01 01:00:00 to 2018-08-03 00:00:00
# Data columns (total 1 columns):
# PJME_MW    145366 non-null float64
# dtypes: float64(1)
# memory usage: 2.2 MB

# %%
# Color pallete for plotting
color_pal = ["#F8766D", "#D39200", "#93AA00",
             "#00BA38", "#00C19F", "#00B9E3",
             "#619CFF", "#DB72FB"]
data.loc[data.index].plot(style='.', figsize=(15,5), color=color_pal[0], title='PJM East')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:245: MatplotlibDeprecationWarning:
# The epoch2num function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   base = dates.epoch2num(dt.asi8 / 1.0e9)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=145366, step=1)

# %%
data.reset_index(drop=True, inplace=True)

# %%
data.columns
# Out:
# Index(['Datetime', 'PJME_MW'], dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=145366, step=1)

# %%
data.tail()
# Out:
#                   Datetime  PJME_MW
# 135088 2017-05-31 19:00:00  33859.0
# 135089 2017-05-31 20:00:00  33223.0
# 135090 2017-05-31 21:00:00  33042.0
# 135091 2017-05-31 22:00:00  32372.0
# 135092 2017-05-31 23:00:00  29577.0

# %% [markdown]
# # Previsão até a data retornada

# %%
"""# countrycode not in trained_models.keys():
    raise Exception("Country code not found:" + countrycode)
*#

# trained_models = /Data/Modeling/trained_models.jbl'
model = trained_models[countrycode]

#df_models = model_score_file = model_scores_parquet
model_last_date = df_models[df_models.countrycode==countrycode].date_end.dt.date.values[0] 
date_max = datetime.strptime(max_forecast_date, '%Y-%m-%d').date()

# Evaluate Model
n_periods = (date_max - model_last_date).days
forecast_data = model.make_future_dataframe(
    periods=n_periods,
    include_history=True
    )
df_forecast = model.predict(forecast_data).set_index('ds')
forecast     = df_forecast.yhat[-n_periods:].rename('forecast')
forecast_low  =  df_forecast.yhat_lower[-n_periods:].rename('forecast_lo')
forecast_up   =  df_forecast.yhat_upper[-n_periods:].rename('forecast_up')
"""
# Out:
# '# countrycode not in trained_models.keys():\n    raise Exception("Country code not found:" + countrycode)\n*#\n\n# trained_models = /Data/Modeling/trained_models.jbl\'\nmodel = trained_models[countrycode]\n\n#df_models = model_score_file = model_scores_parquet\nmodel_last_date = df_models[df_models.countrycode==countrycode].date_end.dt.date.values[0] \ndate_max = datetime.strptime(max_forecast_date, \'%Y-%m-%d\').date()\n\n# Evaluate Model\nn_periods = (date_max - model_last_date).days\nforecast_data = model.make_future_dataframe(\n    periods=n_periods,\n    include_history=True\n    )\ndf_forecast = model.predict(forecast_data).set_index(\'ds\')\nforecast     = df_forecast.yhat[-n_periods:].rename(\'forecast\')\nforecast_low  =  df_forecast.yhat_lower[-n_periods:].rename(\'forecast_lo\')\nforecast_up   =  df_forecast.yhat_upper[-n_periods:].rename(\'forecast_up\')\n'

# %%
model = trained_models

# %%
model_last_date = df_models.date_end.dt.date.values[0]

# %%
print(model_last_date)
# Out:
# 2016-12-30

# %%
data.head()
# Out:
#              Datetime  PJME_MW
# 0 2002-01-01 01:00:00  30393.0
# 1 2002-01-01 02:00:00  29265.0
# 2 2002-01-01 03:00:00  28357.0
# 3 2002-01-01 04:00:00  27899.0
# 4 2002-01-01 05:00:00  28057.0

# %%
data.columns
# Out:
# Index(['Datetime', 'PJME_MW'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 135093 entries, 0 to 135092
# Data columns (total 2 columns):
# Datetime    135093 non-null datetime64[ns]
# PJME_MW     135093 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 3.1 MB

# %%
data.set_index('Datetime', inplace=True)

# %%
data.columns
# Out:
# Index(['PJME_MW'], dtype='object')

# %%
data.head()
# Out:
#                      PJME_MW
# Datetime
# 2002-01-01 01:00:00  30393.0
# 2002-01-01 02:00:00  29265.0
# 2002-01-01 03:00:00  28357.0
# 2002-01-01 04:00:00  27899.0
# 2002-01-01 05:00:00  28057.0

# %%
data.index.min()
# Out:
# Timestamp('2002-01-01 01:00:00')

# %%
split_date = '31-Dec-2016'
pjme_test= data[split_date:max_forecast_date]

# %%
pjme_test.index.max()
# Out:
# Timestamp('2017-05-31 23:00:00')

# %%
# Predict on training set with model
pjme_test_fcst = model.predict(df=pjme_test.reset_index() \
                                   .rename(columns={'Datetime':'ds'}))

# %%
pjme_test_fcst.tail()
# Out:
#                       ds         trend    yhat_lower    yhat_upper  \
# 3642 2017-05-31 19:00:00  30959.025081  30657.957450  40463.784903
# 3643 2017-05-31 20:00:00  30958.992369  30764.497886  40403.146049
# 3644 2017-05-31 21:00:00  30958.959657  30231.227691  39546.996576
# 3645 2017-05-31 22:00:00  30958.926946  28644.528897  37848.824146
# 3646 2017-05-31 23:00:00  30958.894234  26326.215109  35491.015154
#
#        trend_lower   trend_upper  additive_terms  additive_terms_lower  \
# 3642  30340.310751  31462.738790     4689.262745           4689.262745
# 3643  30340.034509  31462.972262     4709.682124           4709.682124
# 3644  30339.758268  31463.324565     3944.734417           3944.734417
# 3645  30339.482026  31463.989995     2335.581191           2335.581191
# 3646  30339.205785  31464.655425      163.793954            163.793954
#
#       additive_terms_upper        daily  ...       weekly  weekly_lower  \
# 3642           4689.262745  4434.149857  ...  1245.050531   1245.050531
# 3643           4709.682124  4447.099954  ...  1242.817044   1242.817044
# 3644           3944.734417  3676.012584  ...  1239.251149   1239.251149
# 3645           2335.581191  2062.039355  ...  1234.362920   1234.362920
# 3646            163.793954  -113.281694  ...  1228.185945   1228.185945
#
#       weekly_upper      yearly  yearly_lower  yearly_upper  \
# 3642   1245.050531 -989.937643   -989.937643   -989.937643
# 3643   1242.817044 -980.234874   -980.234874   -980.234874
# 3644   1239.251149 -970.529316   -970.529316   -970.529316
# 3645   1234.362920 -960.821085   -960.821085   -960.821085
# 3646   1228.185945 -951.110296   -951.110296   -951.110296
#
#       multiplicative_terms  multiplicative_terms_lower  \
# 3642                   0.0                         0.0
# 3643                   0.0                         0.0
# 3644                   0.0                         0.0
# 3645                   0.0                         0.0
# 3646                   0.0                         0.0
#
#       multiplicative_terms_upper          yhat
# 3642                         0.0  35648.287827
# 3643                         0.0  35668.674493
# 3644                         0.0  34903.694074
# 3645                         0.0  33294.508136
# 3646                         0.0  31122.688188
#
# [5 rows x 22 columns]

# %%
data.head()
# Out:
#                      PJME_MW
# Datetime
# 2002-01-01 01:00:00  30393.0
# 2002-01-01 02:00:00  29265.0
# 2002-01-01 03:00:00  28357.0
# 2002-01-01 04:00:00  27899.0
# 2002-01-01 05:00:00  28057.0

# %%
# Color pallete for plotting
color_pal = ["#F8766D", "#D39200", "#93AA00",
             "#00BA38", "#00C19F", "#00B9E3",
             "#619CFF", "#DB72FB"]
data.loc[data.index].plot(style='.', figsize=(15,5), color=color_pal[0], title='PJM East')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:245: MatplotlibDeprecationWarning:
# The epoch2num function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   base = dates.epoch2num(dt.asi8 / 1.0e9)

# %% [markdown]
# # Plot da Previsão e do Real

# %%
data.PJME_MW.plot(label='Real')
#pjme_test_fcst.yhat.plot(label='Forecast')
plt.legend()
plt.xlabel('')
plt.ylabel('#casos (em Milhares)')
plt.grid()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:245: MatplotlibDeprecationWarning:
# The epoch2num function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   base = dates.epoch2num(dt.asi8 / 1.0e9)
