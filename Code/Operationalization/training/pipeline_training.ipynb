# %%
WORKDIR = 'C:/Users/thewr/git/mit_data_science.git/'

notebooks = [
    'Code/DataPrep/data_collection.ipynb',
    'Code/DataPrep/data_prep.ipynb',
    'Code/Analysis/feature_analysis.ipynb',
    'Code/Model/modelling.ipynb',
]

# %%
# %store WORKDIR

error_list = {}
for fname in notebooks:
    print('Notebook:', fname)
    notebook_path = WORKDIR + fname
    try:
        # %run $notebook_path
    except Exception as err:
        print('ERROR: ', err)
        error_list[fname] = err.__str__()
        break
# Out:
# Stored 'WORKDIR' (str)
# Notebook: Code/DataPrep/data_collection.ipynb
# Notebook: Code/DataPrep/data_prep.ipynb
# shape: (145366, 2)
# columns: Index(['Datetime', 'PJME_MW'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145366 entries, 0 to 145365
# Data columns (total 2 columns):
# Datetime    145366 non-null object
# PJME_MW     145366 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 2.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145366 entries, 0 to 145365
# Data columns (total 2 columns):
# Datetime    145366 non-null datetime64[ns]
# PJME_MW     145366 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 2.2 MB
# Notebook: Code/Analysis/feature_analysis.ipynb
# shape: (145366, 2)
# columns: Index(['Datetime', 'PJME_MW'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145366 entries, 0 to 145365
# Data columns (total 2 columns):
# Datetime    145366 non-null datetime64[ns]
# ...
