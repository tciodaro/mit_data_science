# %% [markdown]
# # Using Machine Learning to Forecast Electricity Usage in the future
#
# ## The past dictates the future - or does it?
# Forecasting time series data is different to other forms of machine learning problems due a one main reason - time series data often is correlated with the past. That is, today's value is influenced by, for example, yesterday's value, last week's value etc. This is known as 'autocorrelation' (ie correlating with 'self').
#
# Because time series has autocorrelation, many traditional machine learning algorithm that consider every data point 'independent' don't work well. That is, every prediction is solely based on a particular day's data, and not what happened yesterday, day before etc.
#
# To put it bluntly, traditional machine learning algorithms have **no concept of the passage of time - every single data point is just a 'row in the table'.** It doesn't factor into trends, which as humans, we would intuitively see (e.g. sales went up by 20% this week).
#
# Generally, to make a machine learning model factor data from a particular point's past, you use 'shifting' feature engineering techniques. That is, for example, expressly adding in yesterday's value show as a feature/column for the model to consider.
#
# This illustration will attempt to forecast energy consumption to give a bit of flavour of how time series forecasting works, comparing:
#
# 1. Holtwinters Triple Exponential Smoothing
# 2. Seasonal Autoregression Integrated Moving Average (SARIMA)
# 3. XGBoost Regressor
# 4. LASSO Regularised Regression
# 5. Facebook’s Prophet
#
# ## A showcase of time series forecasting - electricity usage!
# In the electricity industry, being able to forecast the electricity usage in the future is essential and a core part of any electricity retailer's business. The electricity usage of an electricity retailer's customers is generally known as the retailer's 'load' and the usage curve is known as the 'load curve'.
#
# Being able to accurately forecast load is important for a number of reasons:
#
# **Predict the future base load** - electricity retailers need to be able to estimate how much electricity they need to buy off the grid in advance.
# **Smooth out pricing** - if the load is known is advance, electricity retailers can hedge against the price to ensure they aren't caught out when the price skyrockets 3 months into the future.
#
# In a nutshell, the business problem is:
#
# **Given the historical power consumption, what is the expected power consumption for the next 365 days?**
#
# Because we want to predict the daily load for the next 365 days, there are multiple 'time steps' and this form of forecasting is known as 'multi-step forecasting'. In contrast, if you only wanted to predict the load on the 365th day or the load for tomorrow only, this would be known as a 'one-step forecast'.
#
# This dataset is from https://www.kaggle.com/robikscube/hourly-energy-consumption:
#
# > PJM Interconnection LLC (PJM) is a regional transmission organization (RTO) in the United States. It is part of the Eastern Interconnection grid operating an electric transmission system serving all or parts of Delaware, Illinois, Indiana, Kentucky, Maryland, Michigan, New Jersey, North Carolina, Ohio, Pennsylvania, Tennessee, Virginia, West Virginia, and the District of Columbia.
# >
# > The hourly power consumption data comes from PJM's website and are in megawatts (MW).
# >
# > The regions have changed over the years so data may only appear for certain dates per region.

# %% [markdown]
# PJM is one of the world's largest wholesale electricity markets, encompassing over 1,000 companies,  65 million customers and delivered 807 terawatt-hours of electricity in 2018 - [see their annual report](http://https://www.pjm.com/-/media/about-pjm/newsroom/annual-reports/2018-annual-report.ashx?la=en).
#
# We'll use the PJM East Region dataset - which covers the eastern states of the PJM area. There isn't readily available data that identifies which regions are covered, so I'm going to assume (for this analysis) the following States (the coastal ones):
#
# * Delaware
# * Maryland
# * New Jersey
# * North Carolina
# * Pennsylvania
# * Virginia
# * District of Columbia

# %% [markdown]
# # Housekeeping and Preprocessing

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# Configure matplotlib plotting
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
plt.style.use('fivethirtyeight')

from pylab import rcParams
rcParams['figure.figsize'] = 11, 9 #Changes default matplotlib plots to this size

# %% [markdown]
# # Exploratory Data Analysis
#
# We need to first check a few things:
# 1. Duplicate and missing data, as well as spread
# 2. How autocorrelated is this data and its seasonal decomposition

# %%
# Load my EDA helper function created to do some high-level analysis
class EDA():

    df = pd.DataFrame()
    
    def __init__(self, df):
        '''
        Creates EDA object for the DataFrame
        
        Note for time series data, have the index be the timestamp prior to creating this Object.
        
        :param df : DataFrame
        '''
        self.df = df
        
    def missing_values(self):
        '''
        Checks missing values
        
        :return DataFrame
        
        '''
        missing = self.df[self.df.isna().any(axis=1)]
        
        print("Missing values data")
        
        return missing
    
    def duplicate_values(self):
        duplicates = self.df[self.df.duplicated(subset=None, keep='first')==True]
        
        print("Duplicate values data")
        
        return duplicates
        
    def duplicate_indices(self):
        '''
        Check whether the indices have any duplicates
        
        :return DataFrame
        '''        
        duplicate_indices = self.df[self.df.index.duplicated()==True]
        
        print("Duplicate indices")
        
        return duplicate_indices
            
    def summary(self):
        '''
        Return summary/describe of DataFrame
        
        :return DataFrame
        '''
        df = self.df.reset_index() # Reset to include the index
        
        summary = df.describe(include='all').transpose()
        
        print("Summary metrics")
        
        return summary
    
    def pandas_profiling(self):
        import pandas_profiling
        
        self.df.profile_report(style={'full_width':True})  
    
    def histogram_KDE(self):
        ''' 
        :return seaborn plot
        '''       
        sns.pairplot(self.df, diag='kde')
        sns.distplot(kde=True, fit=[st.norm or st.lognorm])
        
    def outliers(self, col):
        ''' 
        Checks outliers - anything outside of 5% to 95% quartile range
        
        :param col : str
            Name of col to be tested
            
        :return DataFrame
        '''
        outliers = self.df[~self.df[col].between(self.df[col].quantile(.05), self.df[col].quantile(.95))]
        
        print("Outliers")
        
        return outliers
        
    def missing_timeseries_points(self, freq='D'):
        '''
        Checks whether there's any missing data points in continuous time series data.
        
        :param freq optional default = 'D' : str
            Frequency compliant with pandas formatting
        
        :return DataFrame
        '''
        # First create date range
        date_range = pd.date_range(start=data.index.min(), end=data.index.max(), freq=freq)

        # Now compare against dataset
        missing_timeseries = self.df.index[~self.df.index.isin(date_range)]
        
        print("Missing timeseries data")
        
        return missing_timeseries

    def corr_heatmap(df):
        fig, ax = plt.subplots(figsize=(10, 6))
        corr = self.df.corr()
        hm = sns.heatmap(round(corr,2), annot=True, cmap="coolwarm",fmt='.2f', linewidths=.05)
        fig.subplots_adjust(top=0.93)
        title = fig.suptitle('Wine Attributes Correlation Heatmap', fontsize=14)

        plt.show()

    def plot_time_series_seasonal_decomp(self, type='add'):
        '''
        Plots seasonal decomposition of timeseries data
        
        :return matplotlib Plot
        '''
        from statsmodels.tsa.seasonal import seasonal_decompose
        decomposition = seasonal_decompose(self.df, model='multiplicative')

        fig = decomposition.plot()
        plt.show()
   
    def time_series_ADF(self):            
        '''
        Returns Augmented Dickey-Fuller Test
        '''
        from statsmodels.tsa.stattools import adfuller as ADF

        series = data['KwH'] # ADF takes series, not DF

        result = ADF(series)

        print('ADF Statistic: %f4.2' % result[0])
        print('P-value %f4.2' % result[1])

# %% [markdown]
# First let's have a look at the dataset - first few lines:

# %%
# Load the Data
data = pd.read_csv("PJME_hourly.csv")

data.set_index('Datetime',inplace=True)

data.index = pd.to_datetime(data.index)

data_copy = data.copy(deep=True) # Make a deep copy, including a copy of the data and the indices
data.head(10)
# Out:
#                      PJME_MW
# Datetime
# 2002-01-01 01:00:00  30393.0
# 2002-01-01 02:00:00  29265.0
# 2002-01-01 03:00:00  28357.0
# 2002-01-01 04:00:00  27899.0
# 2002-01-01 05:00:00  28057.0
# 2002-01-01 06:00:00  28654.0
# 2002-01-01 07:00:00  29308.0
# 2002-01-01 08:00:00  29595.0
# 2002-01-01 09:00:00  29943.0
# 2002-01-01 10:00:00  30692.0

# %% [markdown]
# Next let's have a look at some of the summary EDA data, missing values and duplicates:

# %%
eda_helper = EDA(data)

eda_helper.summary()
# Out:
# Summary metrics
#            count  unique                 top freq               first  \
# Datetime  145366  145362 2014-11-02 02:00:00    2 2002-01-01 01:00:00
# PJME_MW   145366     NaN                 NaT  NaN                 NaT
#
#                last     mean      std    min    25%    50%    75%    max
# Datetime 2018-08-03      NaN      NaN    NaN    NaN    NaN    NaN    NaN
# PJME_MW         NaT  32080.2  6464.01  14544  27573  31421  35650  62009

# %%
eda_helper.missing_values()
# Out:
# Missing values data
# Empty DataFrame
# Columns: [PJME_MW]
# Index: []

# %%
eda_helper.duplicate_values()
# Out:
# Duplicate values data
#                      PJME_MW
# Datetime
# 2002-01-14 08:00:00  35194.0
# 2002-01-14 19:00:00  36504.0
# 2002-01-15 19:00:00  36282.0
# 2002-01-18 19:00:00  36530.0
# 2002-01-19 16:00:00  34078.0
# ...                      ...
# 2018-08-02 20:00:00  44057.0
# 2018-08-02 21:00:00  43256.0
# 2018-08-02 22:00:00  41552.0
# 2018-08-02 23:00:00  38500.0
# 2018-08-03 00:00:00  35486.0
#
# [116925 rows x 1 columns]

# %%
eda_helper.duplicate_indices()
# Out:
# Duplicate indices
#                      PJME_MW
# Datetime
# 2014-11-02 02:00:00  23755.0
# 2015-11-01 02:00:00  21171.0
# 2016-11-06 02:00:00  21692.0
# 2017-11-05 02:00:00  20666.0

# %% [markdown]
# Next we'll process it so the data is at the hourly level:

# %%
def preprocess_data(df):
    # We have duplicates, so we need to de-duplicate it - grabbing first value that pops up for a time series
    df.sort_index()
    df = df.groupby(df.index).first()
    
    #Set freq to H
    df = df.asfreq('H')
    
    return df

# %%
data = preprocess_data(data)

data.index
# Out:
# DatetimeIndex(['2002-01-01 01:00:00', '2002-01-01 02:00:00',
#                '2002-01-01 03:00:00', '2002-01-01 04:00:00',
#                '2002-01-01 05:00:00', '2002-01-01 06:00:00',
#                '2002-01-01 07:00:00', '2002-01-01 08:00:00',
#                '2002-01-01 09:00:00', '2002-01-01 10:00:00',
#                ...
#                '2018-08-02 15:00:00', '2018-08-02 16:00:00',
#                '2018-08-02 17:00:00', '2018-08-02 18:00:00',
#                '2018-08-02 19:00:00', '2018-08-02 20:00:00',
#                '2018-08-02 21:00:00', '2018-08-02 22:00:00',
#                '2018-08-02 23:00:00', '2018-08-03 00:00:00'],
#               dtype='datetime64[ns]', name='Datetime', length=145392, freq='H')

# %% [markdown]
# After preprocessing and cleaning up the data, as well as making sure the frequency is at the hourly level, let's plot the data.

# %%
# Let's visualise the data
data.plot()

plt.show()

# %% [markdown]
# You can see because the frequency is at the hourly level, this is will make forecasting difficult (and its also difficult to visualise too!)
#
# So what we will do is resample it and aggregate it to the daily level

# %%
# We can confirm it is at the right frequency
#daily_data.index

# %% [markdown]
# Let's visualise the data again

# %%
#daily_data.plot()

#plt.show()

# %% [markdown]
# Now there's a tail end where it's not a full day, so it's dropping off.
#
# For our purposes, we will just delete that part day.

# %%
#daily_data = daily_data.drop([daily_data.index.min(), daily_data.index.max()])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 145392 entries, 2002-01-01 01:00:00 to 2018-08-03 00:00:00
# Freq: H
# Data columns (total 1 columns):
# PJME_MW    145362 non-null float64
# dtypes: float64(1)
# memory usage: 2.2 MB

# %%
from datetime import datetime, timedelta
dataset_max_date  = pd.to_datetime('2006-03-26 00:00:00', format='%Y-%m-%d')
dataset_min_date = dataset_max_date - timedelta(days = 30)

# %%
data_used = data[dataset_min_date:dataset_max_date]

# %%
data_used.tail()
# Out:
#                      PJME_MW
# Datetime
# 2006-03-25 20:00:00  32353.0
# 2006-03-25 21:00:00  31744.0
# 2006-03-25 22:00:00  30690.0
# 2006-03-25 23:00:00  29235.0
# 2006-03-26 00:00:00  27408.0

# %% [markdown]
# Good, so there's no missing or duplicate data and you can see the data is from 1 Jan 2002 to 2 August 2018.

# %% [markdown]
# **Seasonal Decomposition**
#
# At a high-level, time series data can be thought of as components put together. That is:
#
# **Data = Level + Trend + Seasonality + Noise**
#
# * **Level**: the average value in the series.
# * **Trend**: the increasing or decreasing value in the series.
# * **Seasonality**: the repeating short-term cycle in the series.
# * **Noise/Residual**: the random variation in the series.
#
# Using the Python statsmodel library, the above components can be 'decomposed' (ie seasonal decomposition):

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(data_used, model='additive')

fig = decomposition.plot()
plt.show()

# %% [markdown]
# One thing that jumps out right now is very difficult to see what's going on, as the graph is very 'packed together'.
#
# More 'traditional' econometric/statistical models, such as Holtwinters and SARIMA, require 3 characteristics for them to work properly, namely:
#
# * Seasonality: the dataset is cyclical in nature
# * Stationarity: the properties of the dataset doesn't change over time
# * Autocorrelation: there is similiar between current and past (ie 'lagged') data points
#
# How about we aggregate up to weekly level to reduce the noise

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
weekly_data = data_used.resample(rule='H').sum()
decomposition = seasonal_decompose(weekly_data, model='additive') # Aggregate to weekly level

fig = decomposition.plot()
plt.show()

# %% [markdown]
# You can see start to see a pattern - electricity usage peak and troughs seem to be very seasonal and repetitive. This makes sense, considering office hours, weather patterns, shopping holidays etc.
#
# Furthermore, you can see the trend of the data seems to be trailing downwards in the last few years.

# %% [markdown]
# Another way to visualise seasonality is to use a heatmap - we can base it on a week to see which days have higher electricity usage.
#
# Note we will drop off 2018 because it's not a full year and will skewer the heatmap.
#
# First let's construct the dataframe table.

# %%
# Create new dataset for heatmap
heatmap_data = data_used.copy()

# First we need to add weekdays as a column
heatmap_data['Weekday_Name'] = data_used.index.weekday_name

# Next we add the year as column and group the data up to annual day of week level
heatmap_data['Year'] =  heatmap_data.index.year
heatmap_data = heatmap_data.groupby(['Year', 'Weekday_Name']).sum()

# Reset index 
heatmap_data = heatmap_data.reset_index()

# We drop off 2018 because it's not a full year
heatmap_data = heatmap_data[heatmap_data['Year'] != 2018]

# Pivot it to a uniform data format for heatmaps
heatmap_data = heatmap_data.pivot(index='Year', columns='Weekday_Name', values='PJME_MW')

# Reorder columns
heatmap_data = heatmap_data[['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']]

heatmap_data.head(100)
# Out:
# Weekday_Name     Monday    Tuesday  Wednesday   Thursday     Friday  \
# Year
# 2006          3166007.0  3167459.0  3183787.0  3132377.0  3873814.0
#
# Weekday_Name   Saturday     Sunday
# Year
# 2006          3598023.0  2878319.0

# %% [markdown]
# Then we visualise it:

# %%
# Visualise electricity load via Heatmap
sns.heatmap(heatmap_data, linewidths=.5, cmap='YlOrRd', cbar=True, cbar_kws={"format": '%1.0f MWh'}).set_title('Heatmap - by Day of Week')
# Out:
# Text(0.5, 1.0, 'Heatmap - by Day of Week')

# %% [markdown]
# So using this you can see (as expected) the weekend has lower electricity use. Many businesses are closed during weekends and therefore this makes sense.

# %% [markdown]
# Now let's do the same thing but over the hours of a day (to sort of see peak operating hours)

# %%
# Create new dataset for heatmap
heatmap_data = data_used.copy()

# First we need to add weekdays as a column
heatmap_data['Hour'] = data_used.index.hour

# Next we add the year as column and group the data up to annual day of week level
heatmap_data['Year'] =  heatmap_data.index.year
heatmap_data = heatmap_data.groupby(['Year', 'Hour']).sum()

# Reset index 
heatmap_data = heatmap_data.reset_index()

# We drop off 2018 because it's not a full year
heatmap_data = heatmap_data[heatmap_data['Year'] != 2018]

# Pivot it to a uniform data format for heatmaps
heatmap_data = heatmap_data.pivot(index='Year', columns='Hour', values='PJME_MW')

heatmap_data.head(100)
# Out:
# Hour        0         1         2         3         4         5         6   \
# Year
# 2006  912894.0  836557.0  812071.0  802814.0  803553.0  822057.0  877950.0
#
# Hour        7          8          9   ...        14        15        16  \
# Year                                  ...
# 2006  961731.0  1007724.0  1021899.0  ...  985731.0  970391.0  962880.0
#
# Hour        17         18         19         20         21         22  \
# Year
# 2006  971686.0  1003713.0  1072466.0  1081929.0  1060993.0  1017105.0
#
# Hour        23
# Year
# 2006  948997.0
#
# [1 rows x 24 columns]

# %%
# Visualise electricity load via Heatmap
sns.heatmap(heatmap_data, linewidths=.5, cmap='YlOrRd', cbar=True, cbar_kws={"format": '%1.0f MWh'}).set_title('Heatmap - by Hour of Day')
# Out:
# Text(0.5, 1.0, 'Heatmap - by Hour of Day')

# %% [markdown]
# Interestingly, it means 11am to 9pm is the busiest peak time of the grid.

# %% [markdown]
# We can also do the same with a 'season plot' - that is, compare each year over 12 months:

# %%
"""
# Create new dataset for heatmap
heatmap_data = data_used.copy()

# First we need to add weekdays as a column
heatmap_data['Month'] = data_used.index.month_name()

# Next we add the year as column and group the data up to annual day of week level
heatmap_data['Year'] =  heatmap_data.index.year
heatmap_data = heatmap_data.groupby(['Year', 'Month']).sum()

# Reset index
heatmap_data = heatmap_data.reset_index()

# We drop off 2018 because it's not a full year
heatmap_data = heatmap_data[heatmap_data['Year'] != 2018]

# Pivot it to a uniform data format for heatmaps
heatmap_data = heatmap_data.pivot(index='Year', columns='Month', values='PJME_MW')

# Reorder columns
heatmap_data = heatmap_data[['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']]

heatmap_data.head(10)
"""
# Out:
# "\n# Create new dataset for heatmap\nheatmap_data = data_used.copy()\n\n# First we need to add weekdays as a column\nheatmap_data['Month'] = data_used.index.month_name()\n\n# Next we add the year as column and group the data up to annual day of week level\nheatmap_data['Year'] =  heatmap_data.index.year\nheatmap_data = heatmap_data.groupby(['Year', 'Month']).sum()\n\n# Reset index\nheatmap_data = heatmap_data.reset_index()\n\n# We drop off 2018 because it's not a full year\nheatmap_data = heatmap_data[heatmap_data['Year'] != 2018]\n\n# Pivot it to a uniform data format for heatmaps\nheatmap_data = heatmap_data.pivot(index='Year', columns='Month', values='PJME_MW')\n\n# Reorder columns\nheatmap_data = heatmap_data[['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']]\n\nheatmap_data.head(10)\n"

# %%
# Visualise electricity load via Heatmap
#sns.heatmap(heatmap_data, linewidths=.5, cmap='YlOrRd', cbar=True, cbar_kws={"format": '%1.0f MWh'}).set_title('Heatmap - by Day of Week')

# %% [markdown]
# # Statistical Test 'Smoke Alarms'
#
# Statistical Tests are a good way to test whether the data is conductive to conventional statistical methods.
#
# There are certain good statistical tests you can apply to a dataset as a 'smoke alarm' test. They are a good indication whether the data is conducive to accurate forecasting.
#
# Both the below statistical tests use Hypothesis Testing and P-Values, which require a cutoff to be picked in advance. The general rule of thumb is 5% - which means there's a only a 5% chance of the statistical tests to be incorrect.
#
# ![image.png](attachment:image.png)
#
#
# '**Stationary**' means the properties of the dataset don't change over time. Non-stationary means the trends, seasonality changes over time and the data is affected by factors other than the passsage of time. A Non-Stationary is sometimes known as a 'Random Walk' - which are notoriously difficult to forecast, because the underlying properties keep changing (e.g. like trying to hit a moving target).
#
# Note that Random Walk is different to a set of 'random numbers' - it's random because the next point is based on a 'random' modification on the first point (e.g. add, minus, multiply). Whereas in a 'random numbers' set, ther would be little relationship between each data point.

# %% [markdown]
# So let's run the test for Stationarity and see the results:

# %%
from statsmodels.tsa.stattools import adfuller as ADF

series = data_used['PJME_MW'] # ADF takes series, not DF

result = ADF(series)

print('ADF Statistic: ', result[0])
print('P-value: {:.20f}'.format(result[1]))
# Out:
# ADF Statistic:  -4.474473127594059
# P-value: 0.00021861323119103953

# %% [markdown]
# '**Heteroskedacity**' refers to instances where the data is evenly distributed along a regression line. Basically it means the data is more closely grouped together and therefore is less 'spiky' (ie has more peaks/troughs).
#
# Heteroskedactic data means the peaks and troughs (ie outliers) are being observed way more often than a 'normally distributed' dataset. This means that a model will have a hard time predicting these spikes.
#
# To alleviate this, heteroskedactic data generally needs to be Box-Cox/log transformed to dampen the extreme peaks/troughs. That is, bringing the data closer together so a model can better fit the whole data and hit the peaks/troughs.

# %% [markdown]
# So let's run the test for Heteroskedacity and see the results:

# %%
from statsmodels.stats.diagnostic import het_breuschpagan as BP
import statsmodels.api as sm
from statsmodels.formula.api import ols

bp_data = data_used.copy()
bp_data['Time_Period'] = range(1, len(bp_data)+1) # Convert time series points into consecutive ints

formula = 'PJME_MW ~ Time_Period' # ie PJME MW depends on Time Period (OLS auto adds Y intercept)

# Next we apply Ordinary Linear Square baseline regression model - as baseline test
model = ols(formula, bp_data).fit()

result = BP(model.resid, model.model.exog)

print('ADF Statistic: ', result[0])
print('P-value: {:.20f}'.format(result[1]))
# Out:
# ADF Statistic:  0.08118830047518544
# P-value: 0.77569347530955934378

# %% [markdown]
# In our case, we got the above results which means:
# * The data is **Stationary** (as the P-Value was below 0.05)
# * The data is **heteroskedactic** (as the P-Value was not below 0.05)

# %% [markdown]
# This explains why the seasonal decomposition and ADF show this data has a lot of noise and crazy swings!!
#
# The consequences of these statistical tests means that the traditional assumptions of linear regression have been violated. That is, more conventional methods of linear regression, statistical F-Tests and T-Tests become ineffective.
#
# Therefore, this forecasting model won't factor in these tests.

# %% [markdown]
# # Autocorrelation
# Autocorrelation is basically how much correlation there is between a particular time point and a prior one - e.g. today's value is highly correleated with last week's value.
#
# Again, Python Statsmodel has a great Autocorrelation Function (ACF) that easily produces this:

# %%
from statsmodels.tsa.stattools import acf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

#fig, ax = plt.subplots(2,1)

# Plot the acf function
plot_acf(data_used['PJME_MW'],lags=720) #alpha 1 suppresses CI

plt.show()

# %% [markdown]
# What the above graph shows is how correlated a prior point is to the current point. The further the number is away from 0, the more correlation there is.
#
# Generally, we would only consider any points above (for positive numbers) and below (for negative numbers) the blue shaded area (the confidence interval) as statistically significant and worth noting.
#
# This shows that yesterday's value has a very high correlation with today's value and there is seasonality - every 6 months it seems to repeat itself.
#
# As eluded earlier, this makes sense if you factor in weather patterns - winter and summer have higher electricity usage due to more heat/cooling needed.
#
# My personal guess is because of weather - winter and summer have higher electricity usage.

# %% [markdown]
# Another modification of this autocorrelation analysis is the Partial Autocorrelation Function (PACF). This function is a variant of ACF, as it finds correlation of the residuals, after removing the effects which are already explained in earlier lags. That way, you don't get a 'compounding' correlation effect.

# %% [markdown]
# This graph shows that the last 90 days have a stronger correlation, but the effect becomes much less obvious the further back you go.

# %%
plot_pacf(data_used['PJME_MW'],lags=720) #alpha 1 suppress CI

plt.show()
# Out:
# C:\Users\thewr\AppData\Roaming\Python\Python37\site-packages\statsmodels\regression\linear_model.py:1406: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %% [markdown]
# # Train Test Split
# Before we continue, let us split the data up between train and split with a specified cutoff date.
#
# Let's pick 3 August 2017 (12 months prior)

# %%
# First we split it up between train and test
# We will aim for a 12 month forecast horizon (ie predict the last 12 months in the dataset)
split_date = data_used.iloc[int(data_used.shape[0] * 0.80)]
print(split_date)
cutoff = '2006-03-20 00:00:00'

data_used.sort_index()

train = data_used[:cutoff]
test = data_used[cutoff:]
# Out:
# PJME_MW    28525.0
# Name: 2006-03-20 00:00:00, dtype: float64

# %%
train.index.min()
# Out:
# Timestamp('2006-02-24 00:00:00')

# %%
train.index.max()
# Out:
# Timestamp('2006-03-20 00:00:00')

# %%
test.index.min()
# Out:
# Timestamp('2006-03-20 00:00:00')

# %%
test.index.max()
# Out:
# Timestamp('2006-03-26 00:00:00')

# %% [markdown]
# Immediately you can see that it is pretty half-decent forecast!
#
# But of course, we need to see the errors/residuals to figure out whether:
# 1. It is normally distributed (i.e. it has no bias to under or over forecasting)
# 2. Whether the errors are autocorrelated (that is, whether the model failed to pick up on any autocorrelation patterns)

# %% [markdown]
# Not bad - the naive forecast actually is quite normally distributed, in terms of its errors.

# %%
from statsmodels.graphics.tsaplots import plot_acf

# Plot the acf function
plot_acf(naive_errors['error'],lags=300) #alpha 1 suppresses CI

plt.title('Naive One-Year Persistence - Residual/Errors Autocorrelation')
plt.show()

# %% [markdown]
# # 1. Holtwinters Triple Exponential Smoothing
# Next we will use a time series forecasting model that takes advantage of the above identified components.
#
# This is known as a 'generative additive model', as the final forecast value is 'adding' together multiple components.
#
# The 'Triple' refers to the three components:
# 1. **Level**
# 2. **Trend**
# 3. **Seasonality**
#
# Holtwinters works really well when the data is seasonal and has trends.
#
# 'Smoothing' basically means more weight is put on more recent data compared to the past.
#
# Note the main hyperparameters for the model are:
# * **Additive vs Multiplicative **(ie 'add' or 'mul')
# * **Box Cox** - to use box cox log transformation to reduce the 'noise' of the data
# * **Alpha** - smoothing factor between 0 and 1. 1 means will always take yesterday's value (naive forecasting). 0 means take simple average of past.
#
# Additive means the formula looks more like this: Data = Level + Trend + Seasonality
#
# Multiplicative means the formula looks more like this: Data = Level x Trend x Seasonality

# %% [markdown]
# We are using Box-Cox as heteroskedatic test before showed data requires dampening to reduce extremes.

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# First we split it up between train and test
htrain = train['PJME_MW'] # HWES takes series, not DF
htest = test['PJME_MW'] # HWES takes series, not DF

model = ExponentialSmoothing(
    htrain
    ,trend='add'
    ,seasonal='add'
    ,freq='H'
    ,seasonal_periods=168 #Default is auto estimated - 4 is quarterly and 7 is weekly
).fit(
    optimized=True # Default is True - auto estimates the other parameters using Grid Search
    ,use_basinhopping=True # Uses Basin Hopping Algorithm for optimising parameters
    ,use_boxcox='log' #Boxcox transformation via log
    #,smoothing_level= # Alpha
    #,smoothing_slope= # Beta
    #,smoothing_seasonal= # Gamma
)

HWES_prediction = model.predict(start=htest.index[0], end=htest.index[-1])
HWES_prediction = HWES_prediction.to_frame().rename(columns={0: 'PJME_MW'})

print("Finished training and predicting")

# Let's see what the model did
model.summary()
# Out:
# Finished training and predicting
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:                    endog   No. Observations:                  577
# Model:             ExponentialSmoothing   SSE                       39562471.392
# Optimized:                         True   AIC                           6769.212
# Trend:                         Additive   BIC                           7518.761
# Seasonal:                      Additive   AICC                          6920.704
# Seasonal Periods:                   168   Date:                 Wed, 09 Sep 2020
# Box-Cox:                           True   Time:                         22:18:22
# Box-Cox Coeff.:                     log
# ==================================================================================
#                            coeff                 code              optimized
# ----------------------------------------------------------------------------------
# smoothing_level                0.9473686                alpha                 True
# smoothing_slope                0.7368421                 beta                 True
# smoothing_seasonal             0.0526355                gamma                 True
# initial_level                  10.293298                  l.0                 True
# initial_slope                   0.000000                  b.0                 True
# initial_seasons.0              0.0439834                  s.0                 True
# initial_seasons.1             -0.0209752                  s.1                 True
# initial_seasons.2             -0.0563070                  s.2                 True
# initial_seasons.3             -0.0669667                  s.3                 True
# initial_seasons.4             -0.0631364                  s.4                 True
# initial_seasons.5             -0.0319616                  s.5                 True
# initial_seasons.6              0.0488959                  s.6                 True
# initial_seasons.7              0.1704330                  s.7                 True
# initial_seasons.8              0.2179964                  s.8                 True
# initial_seasons.9              0.2204710                  s.9                 True
# initial_seasons.10             0.2186223                 s.10                 True
# initial_seasons.11             0.2150516                 s.11                 True
# initial_seasons.12             0.2064399                 s.12                 True
# initial_seasons.13             0.1926841                 s.13                 True
# initial_seasons.14             0.1821570                 s.14                 True
# initial_seasons.15             0.1669149                 s.15                 True
# initial_seasons.16             0.1520196                 s.16                 True
# initial_seasons.17             0.1594666                 s.17                 True
# initial_seasons.18             0.2019670                 s.18                 True
# initial_seasons.19             0.2646991                 s.19                 True
# initial_seasons.20             0.2580259                 s.20                 True
# initial_seasons.21             0.2402900                 s.21                 True
# initial_seasons.22             0.2083662                 s.22                 True
# initial_seasons.23             0.1509134                 s.23                 True
# initial_seasons.24             0.0907309                 s.24                 True
# initial_seasons.25             0.0374159                 s.25                 True
# initial_seasons.26             0.0073529                 s.26                 True
# initial_seasons.27            -0.0118536                 s.27                 True
# initial_seasons.28            -0.0153207                 s.28                 True
# initial_seasons.29            -0.0092874                 s.29                 True
# initial_seasons.30             0.0187500                 s.30                 True
# initial_seasons.31             0.0621554                 s.31                 True
# initial_seasons.32             0.0957588                 s.32                 True
# initial_seasons.33             0.1396698                 s.33                 True
# initial_seasons.34             0.1604473                 s.34                 True
# initial_seasons.35             0.1616863                 s.35                 True
# initial_seasons.36             0.1405819                 s.36                 True
# initial_seasons.37             0.1045196                 s.37                 True
# initial_seasons.38             0.0627607                 s.38                 True
# initial_seasons.39             0.0308711                 s.39                 True
# initial_seasons.40             0.0084957                 s.40                 True
# initial_seasons.41             0.0123159                 s.41                 True
# initial_seasons.42             0.0555791                 s.42                 True
# initial_seasons.43             0.1303807                 s.43                 True
# initial_seasons.44             0.1370462                 s.44                 True
# initial_seasons.45             0.1310344                 s.45                 True
# initial_seasons.46             0.1108433                 s.46                 True
# initial_seasons.47             0.0739232                 s.47                 True
# initial_seasons.48             0.0272535                 s.48                 True
# initial_seasons.49            -0.0155613                 s.49                 True
# initial_seasons.50            -0.0396118                 s.50                 True
# initial_seasons.51            -0.0473564                 s.51                 True
# initial_seasons.52            -0.0438481                 s.52                 True
# initial_seasons.53            -0.0332908                 s.53                 True
# initial_seasons.54            -0.0073751                 s.54                 True
# initial_seasons.55             0.0290303                 s.55                 True
# initial_seasons.56             0.0553237                 s.56                 True
# initial_seasons.57             0.0949893                 s.57                 True
# initial_seasons.58             0.1249573                 s.58                 True
# initial_seasons.59             0.1390511                 s.59                 True
# initial_seasons.60             0.1411996                 s.60                 True
# initial_seasons.61             0.1339706                 s.61                 True
# initial_seasons.62             0.1234619                 s.62                 True
# initial_seasons.63             0.1134764                 s.63                 True
# initial_seasons.64             0.1130535                 s.64                 True
# initial_seasons.65             0.1376364                 s.65                 True
# initial_seasons.66             0.1981134                 s.66                 True
# initial_seasons.67             0.2740879                 s.67                 True
# initial_seasons.68             0.2833895                 s.68                 True
# initial_seasons.69             0.2733925                 s.69                 True
# initial_seasons.70             0.2392510                 s.70                 True
# initial_seasons.71             0.1837643                 s.71                 True
# initial_seasons.72             0.1274936                 s.72                 True
# initial_seasons.73             0.0777841                 s.73                 True
# initial_seasons.74             0.0643489                 s.74                 True
# initial_seasons.75             0.0583628                 s.75                 True
# initial_seasons.76             0.0653647                 s.76                 True
# initial_seasons.77             0.0938796                 s.77                 True
# initial_seasons.78             0.1633270                 s.78                 True
# initial_seasons.79             0.2720263                 s.79                 True
# initial_seasons.80             0.3099148                 s.80                 True
# initial_seasons.81             0.3002567                 s.81                 True
# initial_seasons.82             0.2882482                 s.82                 True
# initial_seasons.83             0.2830062                 s.83                 True
# initial_seasons.84             0.2743452                 s.84                 True
# initial_seasons.85             0.2652448                 s.85                 True
# initial_seasons.86             0.2553010                 s.86                 True
# initial_seasons.87             0.2417269                 s.87                 True
# initial_seasons.88             0.2361278                 s.88                 True
# initial_seasons.89             0.2466076                 s.89                 True
# initial_seasons.90             0.2888310                 s.90                 True
# initial_seasons.91             0.3415228                 s.91                 True
# initial_seasons.92             0.3333325                 s.92                 True
# initial_seasons.93             0.3095172                 s.93                 True
# initial_seasons.94             0.2618370                 s.94                 True
# initial_seasons.95             0.1825804                 s.95                 True
# initial_seasons.96             0.1079902                 s.96                 True
# initial_seasons.97             0.0503455                 s.97                 True
# initial_seasons.98             0.0234572                 s.98                 True
# initial_seasons.99             0.0127837                 s.99                 True
# initial_seasons.100            0.0190817                s.100                 True
# initial_seasons.101            0.0481213                s.101                 True
# initial_seasons.102            0.1234319                s.102                 True
# initial_seasons.103            0.2336915                s.103                 True
# initial_seasons.104            0.2734700                s.104                 True
# initial_seasons.105            0.2670095                s.105                 True
# initial_seasons.106            0.2566115                s.106                 True
# initial_seasons.107            0.2488803                s.107                 True
# initial_seasons.108            0.2342541                s.108                 True
# initial_seasons.109            0.2175062                s.109                 True
# initial_seasons.110            0.2028251                s.110                 True
# initial_seasons.111            0.1845248                s.111                 True
# initial_seasons.112            0.1758440                s.112                 True
# initial_seasons.113            0.1858474                s.113                 True
# initial_seasons.114            0.2315980                s.114                 True
# initial_seasons.115            0.3008832                s.115                 True
# initial_seasons.116            0.3012347                s.116                 True
# initial_seasons.117            0.2809374                s.117                 True
# initial_seasons.118            0.2365820                s.118                 True
# initial_seasons.119            0.1609372                s.119                 True
# initial_seasons.120            0.0786291                s.120                 True
# initial_seasons.121            0.0251756                s.121                 True
# initial_seasons.122            0.0002360                s.122                 True
# initial_seasons.123           -0.0113401                s.123                 True
# initial_seasons.124           -0.0124709                s.124                 True
# initial_seasons.125            0.0133851                s.125                 True
# initial_seasons.126            0.0896482                s.126                 True
# initial_seasons.127            0.2017740                s.127                 True
# initial_seasons.128            0.2367691                s.128                 True
# initial_seasons.129            0.2239687                s.129                 True
# initial_seasons.130            0.2122074                s.130                 True
# initial_seasons.131            0.2019677                s.131                 True
# initial_seasons.132            0.1848063                s.132                 True
# initial_seasons.133            0.1641031                s.133                 True
# initial_seasons.134            0.1488148                s.134                 True
# initial_seasons.135            0.1300241                s.135                 True
# initial_seasons.136            0.1216946                s.136                 True
# initial_seasons.137            0.1312722                s.137                 True
# initial_seasons.138            0.1707761                s.138                 True
# initial_seasons.139            0.2466598                s.139                 True
# initial_seasons.140            0.2528063                s.140                 True
# initial_seasons.141            0.2401304                s.141                 True
# initial_seasons.142            0.2026869                s.142                 True
# initial_seasons.143            0.1304401                s.143                 True
# initial_seasons.144            0.0513432                s.144                 True
# initial_seasons.145           -0.0048205                s.145                 True
# initial_seasons.146           -0.0327659                s.146                 True
# initial_seasons.147           -0.0418688                s.147                 True
# initial_seasons.148           -0.0403520                s.148                 True
# initial_seasons.149           -0.0169378                s.149                 True
# initial_seasons.150            0.0539772                s.150                 True
# initial_seasons.151            0.1614273                s.151                 True
# initial_seasons.152            0.2139862                s.152                 True
# initial_seasons.153            0.2332891                s.153                 True
# initial_seasons.154            0.2406361                s.154                 True
# initial_seasons.155            0.2453101                s.155                 True
# initial_seasons.156            0.2451245                s.156                 True
# initial_seasons.157            0.2410352                s.157                 True
# initial_seasons.158            0.2361545                s.158                 True
# initial_seasons.159            0.2311151                s.159                 True
# initial_seasons.160            0.2293939                s.160                 True
# initial_seasons.161            0.2382378                s.161                 True
# initial_seasons.162            0.2649845                s.162                 True
# initial_seasons.163            0.3026116                s.163                 True
# initial_seasons.164            0.2963120                s.164                 True
# initial_seasons.165            0.2680722                s.165                 True
# initial_seasons.166            0.2217739                s.166                 True
# initial_seasons.167            0.1484342                s.167                 True
# ----------------------------------------------------------------------------------
# """

# %% [markdown]
# Using Holtwinters, data from 2002 to 2017 was used to train the model, while the remaining 2017 to 2018 data was used to test/evaluate the model's accuracy.
#
# Training data is in blue, while test/evaluation data is in red.
#
# Let's evaluate our model using Mean Absolute Error (MAE) and visualise the results

# %%
# Evaluate it's performance using Mean Absolute Error (MAE)
from statsmodels.tools.eval_measures import meanabs

print("MAE HWES ADD: {:.20f}".format(meanabs(htest, HWES_prediction['PJME_MW'])))
# Out:
# MAE HWES ADD: 15174.04163039096965803765

# %%
# Let's visually see the results
plt.scatter(x=train.index, y=train['PJME_MW'], label='Training Data', color='black')
plt.scatter(x=test.index, y=test['PJME_MW'], label='Test Actuals', color='red')
plt.plot(HWES_prediction['PJME_MW'], label='HWES', color='orange')

# Plot Labels, Legends etc
plt.xlabel("Timestamp")
plt.ylabel("MWh")
plt.legend(loc='best')
plt.title('Holtwinters Model (Daily) - Results')

# For clarify, let's limit to only 2017 onwards
plt.xlim(datetime(2006, 2, 20),datetime(2006, 3, 26))

plt.show()

# %% [markdown]
# So it seems Exponential Smoothing is a no-go - let's see how the others fare.

# %% [markdown]
# # XGBoost - Ensemble Learning
#
# XGBoost has gained in popularity recently by being quite good at predicting many different types of problems.
#
# Normally with decision-tree models, you would get the data and create one tree for it. This of course means it is very prone to overfitting and being confused by the unique tendencies of the past data.
#
# To overcome this, you do 'gradient boosting'. At a very high-level, it is analogous to the algorithm creating a decision tree to try to predict the result, figure out how wrong it was, and then create another tree that learns from the first one's 'mistakes'.
#
# This process is then repeated a few hundreds or even a few thousand times, with each tree being 'boosted' by the prior one's mistakes. The algorithm keeps going until it stops improving itself.
#
# The technical aspects of the mathematics are much more complex (and a bit beyond my knowledge to bef honest). If you want more details, the documentation is here.

# %% [markdown]
# ## Feature Engineering
#
# As eluded earlier, most machine learning models don't 'look back' to prior values. Essentially if you have a table, each 'row' is an independent data point and the ML model doesn't consider the prior row's data.
#
# This is problematic for time series data, as shown above, autocorrelation happens.
#
# To address this issue, we use feature engineering to create additional features - in this case, I created 365 extra columns each prior day. Today minus 1 day, Today minus 2 days ... until Today minus 365 days.

# %%
# Feature Engineering first

def preprocess_xgb_data(df, lag_start=1, lag_end=720):
    '''
    Takes data and preprocesses for XGBoost.
    
    :param lag_start default 1 : int
        Lag window start - 1 indicates one-day behind
    :param lag_end default 365 : int
        Lag window start - 365 indicates one-year behind
        
    Returns tuple : (data, target)
    '''
    # Default is add in lag of 365 days of data - ie make the model consider 365 days of prior data
    for i in range(lag_start,lag_end):
        df[f'PJME_MW {i}'] = df.shift(periods=i, freq='H')['PJME_MW']

    df.reset_index(inplace=True)

    # Split out attributes of timestamp - hopefully this lets the algorithm consider seasonality
    df['date_epoch'] = pd.to_numeric(df['Datetime']) # Easier for algorithm to consider consecutive integers, rather than timestamps
    df['dayofweek'] = df['Datetime'].dt.dayofweek
    df['dayofmonth'] = df['Datetime'].dt.day
    df['dayofyear'] = df['Datetime'].dt.dayofyear
    df['weekofyear'] = df['Datetime'].dt.weekofyear
    df['quarter'] = df['Datetime'].dt.quarter
    df['month'] = df['Datetime'].dt.month
    df['year'] = df['Datetime'].dt.year
    
    x = df.drop(columns=['Datetime', 'PJME_MW']) #Don't need timestamp and target
    y = df['PJME_MW'] # Target prediction is the load
    
    return x, y

# %% [markdown]
# Let's see what this looks like:

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 577 entries, 2006-02-24 00:00:00 to 2006-03-20 00:00:00
# Freq: H
# Data columns (total 1 columns):
# PJME_MW    577 non-null float64
# dtypes: float64(1)
# memory usage: 29.0 KB

# %%
example_data = train.copy() #Otherwise it becomes a pointer

example_x, example_y = preprocess_xgb_data(example_data)

example_x.head(10)
# Out:
#    PJME_MW 1  PJME_MW 2  PJME_MW 3  PJME_MW 4  PJME_MW 5  PJME_MW 6  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1    30862.0        NaN        NaN        NaN        NaN        NaN
# 2    28921.0    30862.0        NaN        NaN        NaN        NaN
# 3    27917.0    28921.0    30862.0        NaN        NaN        NaN
# 4    27621.0    27917.0    28921.0    30862.0        NaN        NaN
# 5    27727.0    27621.0    27917.0    28921.0    30862.0        NaN
# 6    28605.0    27727.0    27621.0    27917.0    28921.0    30862.0
# 7    31014.0    28605.0    27727.0    27621.0    27917.0    28921.0
# 8    35022.0    31014.0    28605.0    27727.0    27621.0    27917.0
# 9    36728.0    35022.0    31014.0    28605.0    27727.0    27621.0
#
#    PJME_MW 7  PJME_MW 8  PJME_MW 9  PJME_MW 10  ...  PJME_MW 718  PJME_MW 719  \
# 0        NaN        NaN        NaN         NaN  ...          NaN          NaN
# 1        NaN        NaN        NaN         NaN  ...          NaN          NaN
# 2        NaN        NaN        NaN         NaN  ...          NaN          NaN
# 3        NaN        NaN        NaN         NaN  ...          NaN          NaN
# 4        NaN        NaN        NaN         NaN  ...          NaN          NaN
# 5        NaN        NaN        NaN         NaN  ...          NaN          NaN
# 6        NaN        NaN        NaN         NaN  ...          NaN          NaN
# 7    30862.0        NaN        NaN         NaN  ...          NaN          NaN
# 8    28921.0    30862.0        NaN         NaN  ...          NaN          NaN
# 9    27917.0    28921.0    30862.0         NaN  ...          NaN          NaN
#
#             date_epoch  dayofweek  dayofmonth  dayofyear  weekofyear  quarter  \
# 0  1140739200000000000          4          24         55           8        1
# 1  1140742800000000000          4          24         55           8        1
# 2  1140746400000000000          4          24         55           8        1
# 3  1140750000000000000          4          24         55           8        1
# 4  1140753600000000000          4          24         55           8        1
# 5  1140757200000000000          4          24         55           8        1
# 6  1140760800000000000          4          24         55           8        1
# 7  1140764400000000000          4          24         55           8        1
# 8  1140768000000000000          4          24         55           8        1
# 9  1140771600000000000          4          24         55           8        1
#
#    month  year
# 0      2  2006
# 1      2  2006
# 2      2  2006
# 3      2  2006
# 4      2  2006
# 5      2  2006
# 6      2  2006
# 7      2  2006
# 8      2  2006
# 9      2  2006
#
# [10 rows x 727 columns]

# %% [markdown]
# Now we need to split the time series between training and test - like what we did before.
#
# Cross validation is harder in this case, as the datasets need to be sequential.
#
# We will also need to specify features and labels (ie the target we want to predict).

# %%
xtrain = train.copy() #Otherwise it becomes a pointer
xtest = test.copy() # Otherwise it becomes a pointer

train_feature, train_label = preprocess_xgb_data(xtrain)
test_feature, test_label = preprocess_xgb_data(xtest)

# %% [markdown]
# Finally we train the model and see how well it performed (using MAE) and visualise the results.
#
# To train the model, again I split the data into two parts: Training from 2002 to 2017 and Evaluation/Testing from 2017 to 2018.
#
# In this case, I used 1000 runs and a maximum depth of each tree to be 6. That is, it does 1000 runs (or less if it stops improving), with each tree having a max of 6 levels.
#
# As a tree-based algorithm, generally XGBoost doesn't handle trends in data well compared to linear models. However, given as shown above in the ADF test, the data is stationary, trend is not really an issue and we can proceed. Otherwise we would need to de-trend the data first as part of preprocessing.

# %%
#Train and predict using XGBoost
from xgboost import XGBRegressor
from sklearn.model_selection import KFold, train_test_split

# We will try with 1000 trees and a maximum depth of each tree to be 5
# Early stop if the model hasn't improved in 100 rounds
model = XGBRegressor(
    max_depth=6 # Default - 6
    ,n_estimators=1000
    ,booster='gbtree'
    ,colsample_bytree=1 # Subsample ratio of columns when constructing each tree - default 1
    ,eta=0.3 # Learning Rate - default 0.3
    ,importance_type='weight' # Default is gain
)
model.fit(
    train_feature
    ,train_label
    ,eval_set=[(train_feature, train_label)]
    ,eval_metric='mae'
    ,verbose=True
    ,early_stopping_rounds=100 # Stop after 100 rounds if it doesn't after 100 times
)

xtest['PJME_MW Prediction'] = model.predict(test_feature)
XGB_prediction = xtest[['Datetime', 'PJME_MW Prediction']].set_index('Datetime')
# Out:
# [0]	validation_0-mae:22348.34766
# Will train until validation_0-mae hasn't improved in 100 rounds.
# [1]	validation_0-mae:15687.17871
# [2]	validation_0-mae:11013.49121
# [3]	validation_0-mae:7731.97070
# [4]	validation_0-mae:5438.39209
# [5]	validation_0-mae:3825.59888
# [6]	validation_0-mae:2701.74170
# [7]	validation_0-mae:1918.88538
# [8]	validation_0-mae:1363.95666
# [9]	validation_0-mae:968.80914
# [10]	validation_0-mae:691.62891
# [11]	validation_0-mae:498.59418
# [12]	validation_0-mae:372.78900
# [13]	validation_0-mae:284.96155
# [14]	validation_0-mae:231.40520
# [15]	validation_0-mae:197.64574
# [16]	validation_0-mae:175.74056
# [17]	validation_0-mae:152.00365
# [18]	validation_0-mae:135.19609
# [19]	validation_0-mae:118.55608
# [20]	validation_0-mae:104.04268
# [21]	validation_0-mae:96.79738
# [22]	validation_0-mae:91.97827
# [23]	validation_0-mae:84.82215
# [24]	validation_0-mae:81.81409
# [25]	validation_0-mae:77.61343
# [26]	validation_0-mae:74.71069
# [27]	validation_0-mae:72.65722
# [28]	validation_0-mae:70.66646
# [29]	validation_0-mae:66.09789
# [30]	validation_0-mae:64.74209
# [31]	validation_0-mae:61.11578
# [32]	validation_0-mae:59.54671
# [33]	validation_0-mae:58.70541
# [34]	validation_0-mae:57.88243
# [35]	validation_0-mae:56.60152
# [36]	validation_0-mae:53.11607
# [37]	validation_0-mae:52.08914
# [38]	validation_0-mae:51.22999
# [39]	validation_0-mae:50.12000
# [40]	validation_0-mae:48.79105
# [41]	validation_0-mae:47.50552
# [42]	validation_0-mae:44.47577
# [43]	validation_0-mae:43.11436
# [44]	validation_0-mae:42.12845
# [45]	validation_0-mae:41.42195
# [46]	validation_0-mae:39.76552
# [47]	validation_0-mae:38.85968
# [48]	validation_0-mae:37.55979
# [49]	validation_0-mae:36.95660
# [50]	validation_0-mae:36.34684
# [51]	validation_0-mae:35.20436
# [52]	validation_0-mae:33.82395
# [53]	validation_0-mae:33.14619
# [54]	validation_0-mae:31.06766
# [55]	validation_0-mae:30.08858
# [56]	validation_0-mae:28.86968
# [57]	validation_0-mae:27.95331
# [58]	validation_0-mae:26.08523
# [59]	validation_0-mae:25.42722
# [60]	validation_0-mae:24.97744
# [61]	validation_0-mae:24.35264
# [62]	validation_0-mae:22.56744
# [63]	validation_0-mae:21.83566
# [64]	validation_0-mae:21.14306
# [65]	validation_0-mae:19.44665
# [66]	validation_0-mae:19.03564
# [67]	validation_0-mae:18.54753
# [68]	validation_0-mae:18.18409
# [69]	validation_0-mae:17.42916
# [70]	validation_0-mae:17.01090
# [71]	validation_0-mae:16.33655
# [72]	validation_0-mae:16.04020
# [73]	validation_0-mae:15.77341
# [74]	validation_0-mae:15.53005
# [75]	validation_0-mae:14.75627
# [76]	validation_0-mae:13.99799
# [77]	validation_0-mae:13.79187
# [78]	validation_0-mae:13.35600
# [79]	validation_0-mae:13.04384
# [80]	validation_0-mae:12.69170
# [81]	validation_0-mae:12.31972
# [82]	validation_0-mae:12.02546
# [83]	validation_0-mae:11.84146
# [84]	validation_0-mae:11.56064
# [85]	validation_0-mae:11.06090
# [86]	validation_0-mae:10.68288
# [87]	validation_0-mae:10.34584
# [88]	validation_0-mae:9.98550
# [89]	validation_0-mae:9.73155
# [90]	validation_0-mae:9.48922
# [91]	validation_0-mae:8.97950
# [92]	validation_0-mae:8.76090
# [93]	validation_0-mae:8.53571
# [94]	validation_0-mae:8.28350
# [95]	validation_0-mae:8.14700
# [96]	validation_0-mae:7.71191
# [97]	validation_0-mae:7.37247
# [98]	validation_0-mae:6.98103
# [99]	validation_0-mae:6.82252
# [100]	validation_0-mae:6.58488
# [101]	validation_0-mae:6.42608
# [102]	validation_0-mae:6.13197
# [103]	validation_0-mae:5.97488
# [104]	validation_0-mae:5.88539
# [105]	validation_0-mae:5.58710
# [106]	validation_0-mae:5.48605
# [107]	validation_0-mae:5.33027
# [108]	validation_0-mae:5.24417
# [109]	validation_0-mae:5.05467
# [110]	validation_0-mae:4.87133
# [111]	validation_0-mae:4.65602
# [112]	validation_0-mae:4.56354
# [113]	validation_0-mae:4.49228
# [114]	validation_0-mae:4.21635
# [115]	validation_0-mae:4.07185
# [116]	validation_0-mae:3.88152
# [117]	validation_0-mae:3.67635
# [118]	validation_0-mae:3.48709
# [119]	validation_0-mae:3.39930
# [120]	validation_0-mae:3.22697
# [121]	validation_0-mae:3.14323
# [122]	validation_0-mae:2.97240
# [123]	validation_0-mae:2.87293
# [124]	validation_0-mae:2.77275
# [125]	validation_0-mae:2.66813
# [126]	validation_0-mae:2.56616
# [127]	validation_0-mae:2.53295
# [128]	validation_0-mae:2.45631
# [129]	validation_0-mae:2.34673
# [130]	validation_0-mae:2.29849
# [131]	validation_0-mae:2.25664
# [132]	validation_0-mae:2.18660
# [133]	validation_0-mae:2.11796
# [134]	validation_0-mae:2.07856
# [135]	validation_0-mae:2.03248
# [136]	validation_0-mae:1.99014
# [137]	validation_0-mae:1.93597
# [138]	validation_0-mae:1.85621
# [139]	validation_0-mae:1.80988
# [140]	validation_0-mae:1.71566
# [141]	validation_0-mae:1.67009
# [142]	validation_0-mae:1.61463
# [143]	validation_0-mae:1.58335
# [144]	validation_0-mae:1.54985
# [145]	validation_0-mae:1.47103
# [146]	validation_0-mae:1.40420
# [147]	validation_0-mae:1.33841
# [148]	validation_0-mae:1.30219
# [149]	validation_0-mae:1.24453
# [150]	validation_0-mae:1.18036
# [151]	validation_0-mae:1.14690
# [152]	validation_0-mae:1.11335
# [153]	validation_0-mae:1.09201
# [154]	validation_0-mae:1.04625
# [155]	validation_0-mae:0.98105
# [156]	validation_0-mae:0.95305
# [157]	validation_0-mae:0.91393
# [158]	validation_0-mae:0.89914
# [159]	validation_0-mae:0.86314
# [160]	validation_0-mae:0.81124
# [161]	validation_0-mae:0.79912
# [162]	validation_0-mae:0.76651
# [163]	validation_0-mae:0.75999
# [164]	validation_0-mae:0.74192
# [165]	validation_0-mae:0.72740
# [166]	validation_0-mae:0.68622
# [167]	validation_0-mae:0.66273
# [168]	validation_0-mae:0.64714
# [169]	validation_0-mae:0.60222
# [170]	validation_0-mae:0.58115
# [171]	validation_0-mae:0.54966
# [172]	validation_0-mae:0.54006
# [173]	validation_0-mae:0.52846
# [174]	validation_0-mae:0.51961
# [175]	validation_0-mae:0.50926
# [176]	validation_0-mae:0.49822
# [177]	validation_0-mae:0.48685
# [178]	validation_0-mae:0.47043
# [179]	validation_0-mae:0.46020
# [180]	validation_0-mae:0.44914
# [181]	validation_0-mae:0.43053
# [182]	validation_0-mae:0.41847
# [183]	validation_0-mae:0.39418
# [184]	validation_0-mae:0.38755
# [185]	validation_0-mae:0.38158
# [186]	validation_0-mae:0.37361
# [187]	validation_0-mae:0.36679
# [188]	validation_0-mae:0.35868
# [189]	validation_0-mae:0.33396
# [190]	validation_0-mae:0.32639
# [191]	validation_0-mae:0.31469
# [192]	validation_0-mae:0.30591
# [193]	validation_0-mae:0.30027
# [194]	validation_0-mae:0.29446
# [195]	validation_0-mae:0.28946
# [196]	validation_0-mae:0.27885
# [197]	validation_0-mae:0.27199
# [198]	validation_0-mae:0.26843
# [199]	validation_0-mae:0.26070
# [200]	validation_0-mae:0.25559
# [201]	validation_0-mae:0.24741
# [202]	validation_0-mae:0.23677
# [203]	validation_0-mae:0.22973
# [204]	validation_0-mae:0.22603
# [205]	validation_0-mae:0.22292
# [206]	validation_0-mae:0.21617
# [207]	validation_0-mae:0.20744
# [208]	validation_0-mae:0.20344
# [209]	validation_0-mae:0.19944
# [210]	validation_0-mae:0.18894
# [211]	validation_0-mae:0.17811
# [212]	validation_0-mae:0.17160
# [213]	validation_0-mae:0.16764
# [214]	validation_0-mae:0.16197
# [215]	validation_0-mae:0.15784
# [216]	validation_0-mae:0.15604
# [217]	validation_0-mae:0.15159
# [218]	validation_0-mae:0.14989
# [219]	validation_0-mae:0.14750
# [220]	validation_0-mae:0.14413
# [221]	validation_0-mae:0.13981
# [222]	validation_0-mae:0.13373
# [223]	validation_0-mae:0.12824
# [224]	validation_0-mae:0.12023
# [225]	validation_0-mae:0.11789
# [226]	validation_0-mae:0.11652
# [227]	validation_0-mae:0.11238
# [228]	validation_0-mae:0.10931
# [229]	validation_0-mae:0.10605
# [230]	validation_0-mae:0.10465
# [231]	validation_0-mae:0.10260
# [232]	validation_0-mae:0.10097
# [233]	validation_0-mae:0.09884
# [234]	validation_0-mae:0.09731
# [235]	validation_0-mae:0.09473
# [236]	validation_0-mae:0.09252
# [237]	validation_0-mae:0.08916
# [238]	validation_0-mae:0.08616
# [239]	validation_0-mae:0.08504
# [240]	validation_0-mae:0.08221
# [241]	validation_0-mae:0.07862
# [242]	validation_0-mae:0.07569
# [243]	validation_0-mae:0.07369
# [244]	validation_0-mae:0.07209
# [245]	validation_0-mae:0.07035
# [246]	validation_0-mae:0.06849
# [247]	validation_0-mae:0.06708
# [248]	validation_0-mae:0.06562
# [249]	validation_0-mae:0.06245
# [250]	validation_0-mae:0.06061
# [251]	validation_0-mae:0.05768
# [252]	validation_0-mae:0.05640
# [253]	validation_0-mae:0.05495
# [254]	validation_0-mae:0.05316
# [255]	validation_0-mae:0.05260
# [256]	validation_0-mae:0.05112
# [257]	validation_0-mae:0.04992
# [258]	validation_0-mae:0.04802
# [259]	validation_0-mae:0.04659
# [260]	validation_0-mae:0.04460
# [261]	validation_0-mae:0.04292
# [262]	validation_0-mae:0.04195
# [263]	validation_0-mae:0.04138
# [264]	validation_0-mae:0.04028
# [265]	validation_0-mae:0.03964
# [266]	validation_0-mae:0.03834
# [267]	validation_0-mae:0.03759
# [268]	validation_0-mae:0.03681
# [269]	validation_0-mae:0.03584
# [270]	validation_0-mae:0.03442
# [271]	validation_0-mae:0.03278
# [272]	validation_0-mae:0.03133
# [273]	validation_0-mae:0.02988
# [274]	validation_0-mae:0.02907
# [275]	validation_0-mae:0.02833
# [276]	validation_0-mae:0.02776
# [277]	validation_0-mae:0.02721
# [278]	validation_0-mae:0.02677
# [279]	validation_0-mae:0.02612
# [280]	validation_0-mae:0.02567
# [281]	validation_0-mae:0.02364
# [282]	validation_0-mae:0.02332
# [283]	validation_0-mae:0.02291
# [284]	validation_0-mae:0.02250
# [285]	validation_0-mae:0.02146
# [286]	validation_0-mae:0.02082
# [287]	validation_0-mae:0.02046
# [288]	validation_0-mae:0.01924
# [289]	validation_0-mae:0.01885
# [290]	validation_0-mae:0.01819
# [291]	validation_0-mae:0.01747
# [292]	validation_0-mae:0.01684
# [293]	validation_0-mae:0.01631
# [294]	validation_0-mae:0.01609
# [295]	validation_0-mae:0.01579
# [296]	validation_0-mae:0.01532
# [297]	validation_0-mae:0.01505
# [298]	validation_0-mae:0.01483
# [299]	validation_0-mae:0.01462
# [300]	validation_0-mae:0.01418
# [301]	validation_0-mae:0.01377
# [302]	validation_0-mae:0.01321
# [303]	validation_0-mae:0.01249
# [304]	validation_0-mae:0.01222
# [305]	validation_0-mae:0.01195
# [306]	validation_0-mae:0.01171
# [307]	validation_0-mae:0.01145
# [308]	validation_0-mae:0.01127
# [309]	validation_0-mae:0.01076
# [310]	validation_0-mae:0.01035
# [311]	validation_0-mae:0.01017
# [312]	validation_0-mae:0.01002
# [313]	validation_0-mae:0.00963
# [314]	validation_0-mae:0.00914
# [315]	validation_0-mae:0.00884
# [316]	validation_0-mae:0.00856
# [317]	validation_0-mae:0.00832
# [318]	validation_0-mae:0.00807
# [319]	validation_0-mae:0.00790
# [320]	validation_0-mae:0.00765
# [321]	validation_0-mae:0.00744
# [322]	validation_0-mae:0.00730
# [323]	validation_0-mae:0.00722
# [324]	validation_0-mae:0.00702
# [325]	validation_0-mae:0.00686
# [326]	validation_0-mae:0.00680
# [327]	validation_0-mae:0.00667
# [328]	validation_0-mae:0.00658
# [329]	validation_0-mae:0.00625
# [330]	validation_0-mae:0.00610
# [331]	validation_0-mae:0.00606
# [332]	validation_0-mae:0.00576
# [333]	validation_0-mae:0.00560
# [334]	validation_0-mae:0.00545
# [335]	validation_0-mae:0.00534
# [336]	validation_0-mae:0.00509
# [337]	validation_0-mae:0.00496
# [338]	validation_0-mae:0.00482
# [339]	validation_0-mae:0.00481
# [340]	validation_0-mae:0.00470
# [341]	validation_0-mae:0.00463
# [342]	validation_0-mae:0.00449
# [343]	validation_0-mae:0.00444
# [344]	validation_0-mae:0.00437
# [345]	validation_0-mae:0.00431
# [346]	validation_0-mae:0.00428
# [347]	validation_0-mae:0.00422
# [348]	validation_0-mae:0.00419
# [349]	validation_0-mae:0.00417
# [350]	validation_0-mae:0.00415
# [351]	validation_0-mae:0.00415
# [352]	validation_0-mae:0.00415
# [353]	validation_0-mae:0.00415
# [354]	validation_0-mae:0.00415
# [355]	validation_0-mae:0.00415
# [356]	validation_0-mae:0.00415
# [357]	validation_0-mae:0.00415
# [358]	validation_0-mae:0.00415
# [359]	validation_0-mae:0.00415
# [360]	validation_0-mae:0.00415
# [361]	validation_0-mae:0.00415
# [362]	validation_0-mae:0.00415
# [363]	validation_0-mae:0.00415
# [364]	validation_0-mae:0.00415
# [365]	validation_0-mae:0.00415
# [366]	validation_0-mae:0.00415
# [367]	validation_0-mae:0.00415
# [368]	validation_0-mae:0.00415
# [369]	validation_0-mae:0.00415
# [370]	validation_0-mae:0.00415
# [371]	validation_0-mae:0.00415
# [372]	validation_0-mae:0.00415
# [373]	validation_0-mae:0.00415
# [374]	validation_0-mae:0.00415
# [375]	validation_0-mae:0.00415
# [376]	validation_0-mae:0.00415
# [377]	validation_0-mae:0.00415
# [378]	validation_0-mae:0.00415
# [379]	validation_0-mae:0.00415
# [380]	validation_0-mae:0.00415
# [381]	validation_0-mae:0.00415
# [382]	validation_0-mae:0.00415
# [383]	validation_0-mae:0.00415
# [384]	validation_0-mae:0.00415
# [385]	validation_0-mae:0.00415
# [386]	validation_0-mae:0.00415
# [387]	validation_0-mae:0.00415
# [388]	validation_0-mae:0.00415
# [389]	validation_0-mae:0.00415
# [390]	validation_0-mae:0.00415
# [391]	validation_0-mae:0.00415
# [392]	validation_0-mae:0.00415
# [393]	validation_0-mae:0.00415
# [394]	validation_0-mae:0.00415
# [395]	validation_0-mae:0.00415
# [396]	validation_0-mae:0.00415
# [397]	validation_0-mae:0.00415
# [398]	validation_0-mae:0.00415
# [399]	validation_0-mae:0.00415
# [400]	validation_0-mae:0.00415
# [401]	validation_0-mae:0.00415
# [402]	validation_0-mae:0.00415
# [403]	validation_0-mae:0.00415
# [404]	validation_0-mae:0.00415
# [405]	validation_0-mae:0.00415
# [406]	validation_0-mae:0.00415
# [407]	validation_0-mae:0.00415
# [408]	validation_0-mae:0.00415
# [409]	validation_0-mae:0.00415
# [410]	validation_0-mae:0.00415
# [411]	validation_0-mae:0.00415
# [412]	validation_0-mae:0.00415
# [413]	validation_0-mae:0.00415
# [414]	validation_0-mae:0.00415
# [415]	validation_0-mae:0.00415
# [416]	validation_0-mae:0.00415
# [417]	validation_0-mae:0.00415
# [418]	validation_0-mae:0.00415
# [419]	validation_0-mae:0.00415
# [420]	validation_0-mae:0.00415
# [421]	validation_0-mae:0.00415
# [422]	validation_0-mae:0.00415
# [423]	validation_0-mae:0.00415
# [424]	validation_0-mae:0.00415
# [425]	validation_0-mae:0.00415
# [426]	validation_0-mae:0.00415
# [427]	validation_0-mae:0.00415
# [428]	validation_0-mae:0.00415
# [429]	validation_0-mae:0.00415
# [430]	validation_0-mae:0.00415
# [431]	validation_0-mae:0.00415
# [432]	validation_0-mae:0.00415
# [433]	validation_0-mae:0.00415
# [434]	validation_0-mae:0.00415
# [435]	validation_0-mae:0.00415
# [436]	validation_0-mae:0.00415
# [437]	validation_0-mae:0.00415
# [438]	validation_0-mae:0.00415
# [439]	validation_0-mae:0.00415
# [440]	validation_0-mae:0.00415
# [441]	validation_0-mae:0.00415
# [442]	validation_0-mae:0.00415
# [443]	validation_0-mae:0.00415
# [444]	validation_0-mae:0.00415
# [445]	validation_0-mae:0.00415
# [446]	validation_0-mae:0.00415
# [447]	validation_0-mae:0.00415
# [448]	validation_0-mae:0.00415
# [449]	validation_0-mae:0.00415
# [450]	validation_0-mae:0.00415
# [451]	validation_0-mae:0.00415
# Stopping. Best iteration:
# [351]	validation_0-mae:0.00415

# %%
from sklearn.metrics import mean_absolute_error

print("MAE XGB: {:.20f}".format(mean_absolute_error(test_label, XGB_prediction['PJME_MW Prediction'])))
# Out:
# MAE XGB: 732.62354525862065202091

# %%
# Let's visually see the results
plt.scatter(x=train.index, y=train['PJME_MW'], label='Training Data', color='black')
plt.scatter(x=test.index, y=test['PJME_MW'], label='Test Actuals', color='red')
plt.plot(XGB_prediction, label='XGB One-Step Ahead', color='orange')

# Plot Labels, Legends etc
plt.xlabel("Timestamp")
plt.ylabel("MWh")
plt.legend(loc='best')
plt.title('XGBoost Model One-Step Ahead (Daily) - Results')

# For clarify, let's limit to only 2015 onwards
plt.xlim(datetime(2006, 2, 20),datetime(2006, 3, 27))


plt.show()

# %% [markdown]
# The results of the model are fairly accurate!
#
# However, caveat is that because the model knows about yesterday's value. Therefore, the 'forecast horizon' (ie the maximum length of time it can predict into the future) is only 1 day. This is also known as a 'One-Step Ahead Forecast'.
#
# If you only have yesterday's value, you can only predict today's value. If you only have today's value, you can only predict tomorrow's value.

# %% [markdown]
# Now let's see what the algorithm considered most important - we'll grab the **Top 10 features by weight**.
#
# The weight is the percentage representing the relative number of times a particular feature occurs in the trees of the model. It's a rough way of saying the more times you reference a particular feature, the more likely it is important.

# %%
import xgboost as xgb

xgb.plot_importance(model, max_num_features=10, importance_type='weight') # "weight” is the number of times a feature appears in a tree

plt.show()

# %% [markdown]
# Seems like yesterday's value is the biggest factor in determining today's value! This, again, makes sense, given how the autocorrelation function showed yesterday's value had the biggest correlation with today's value.

# %% [markdown]
# ## An alternative feature engineering approach - let's include lag without data leakage
# Let's try to make the XGBoost model more than One-Step Ahead - we'll only feature engineer:
#
# - Day of the Week
# - Day of the Month
# - Day of the Year
# - Week of the Year
# - Month
# - Year
#
# Hopefully this is enough for the model to artificially pick up 'seasonality' factors - e.g., if same day of week, might be correlated.
#
# However, as forecast horizon is 365 days, we can still include lag-365 to lag-720 days data (i.e. year-before last year's data).

# %%
#all_data = data.copy()
#all_data = all_data[:dataset_max_date]

# %%
# So because we need the lag data, we need to preprocess then do the split
data_preprocessed = data_used.copy()
feature, label = preprocess_xgb_data(data_preprocessed, lag_start=575, lag_end=720)

# We will aim for a 12 month forecast horizon (ie predict the last 365 days in the dataset)
train_feature = feature[:576]
train_label = label[:576]

test_feature = feature[576:]
test_label = label[576:]

# %%
data_preprocessed.shape
# Out:
# (721, 155)

# %%
xtest.shape
# Out:
# (145, 730)

# %%
test_feature.shape
# Out:
# (145, 153)

# %%
#Train and predict using XGBoost
from xgboost import XGBRegressor
from sklearn.model_selection import KFold, train_test_split

# We will try with 1000 trees and a maximum depth of each tree to be 5
# Early stop if the model hasn't improved in 100 rounds
model = XGBRegressor(
    max_depth=6 # Default - 6
    ,n_estimators=1000
    ,booster='gbtree'
    ,colsample_bytree=1 # Subsample ratio of columns when constructing each tree - default 1
    ,eta=0.3 # Learning Rate - default 0.3
    ,importance_type='gain' # Default is gain
)
model.fit(
    train_feature
    ,train_label
    ,eval_set=[(train_feature, train_label)]
    ,eval_metric='mae'
    ,verbose=True
    ,early_stopping_rounds=100 # Stop after 100 rounds if it doesn't after 100 times
)

xtest['PJME_MW'] = model.predict(test_feature)
XGB_prediction_no_lag = xtest[['Datetime', 'PJME_MW Prediction']].set_index('Datetime')
XGB_prediction_no_lag = XGB_prediction_no_lag.rename(columns={'PJME_MW Prediction': 'PJME_MW'})
# Out:
# [0]	validation_0-mae:22323.03906
# Will train until validation_0-mae hasn't improved in 100 rounds.
# [1]	validation_0-mae:15658.98828
# [2]	validation_0-mae:11014.66602
# [3]	validation_0-mae:7754.75439
# [4]	validation_0-mae:5548.25879
# [5]	validation_0-mae:4136.00000
# [6]	validation_0-mae:3146.52808
# [7]	validation_0-mae:2491.85571
# [8]	validation_0-mae:2076.00830
# [9]	validation_0-mae:1766.70239
# [10]	validation_0-mae:1568.02210
# [11]	validation_0-mae:1438.46399
# [12]	validation_0-mae:1330.00830
# [13]	validation_0-mae:1286.47669
# [14]	validation_0-mae:1210.29211
# [15]	validation_0-mae:1134.45398
# [16]	validation_0-mae:1096.02405
# [17]	validation_0-mae:1047.44019
# [18]	validation_0-mae:980.24554
# [19]	validation_0-mae:957.23914
# [20]	validation_0-mae:937.12219
# [21]	validation_0-mae:897.70532
# [22]	validation_0-mae:873.87915
# [23]	validation_0-mae:859.73157
# [24]	validation_0-mae:844.28418
# [25]	validation_0-mae:784.07770
# [26]	validation_0-mae:752.97913
# [27]	validation_0-mae:747.09613
# [28]	validation_0-mae:719.27313
# [29]	validation_0-mae:702.57965
# [30]	validation_0-mae:668.03857
# [31]	validation_0-mae:652.61127
# [32]	validation_0-mae:621.89612
# [33]	validation_0-mae:589.23590
# [34]	validation_0-mae:567.47961
# [35]	validation_0-mae:538.49188
# [36]	validation_0-mae:515.31976
# [37]	validation_0-mae:496.70926
# [38]	validation_0-mae:478.64899
# [39]	validation_0-mae:472.64822
# [40]	validation_0-mae:455.02918
# [41]	validation_0-mae:448.87415
# [42]	validation_0-mae:433.54672
# [43]	validation_0-mae:418.22903
# [44]	validation_0-mae:405.49399
# [45]	validation_0-mae:395.95151
# [46]	validation_0-mae:390.76642
# [47]	validation_0-mae:380.48206
# [48]	validation_0-mae:374.34055
# [49]	validation_0-mae:366.52963
# [50]	validation_0-mae:363.34515
# [51]	validation_0-mae:353.39197
# [52]	validation_0-mae:336.35861
# [53]	validation_0-mae:320.50238
# [54]	validation_0-mae:312.14761
# [55]	validation_0-mae:299.20844
# [56]	validation_0-mae:290.60742
# [57]	validation_0-mae:284.47354
# [58]	validation_0-mae:272.88455
# [59]	validation_0-mae:264.02289
# [60]	validation_0-mae:261.80194
# [61]	validation_0-mae:251.00928
# [62]	validation_0-mae:244.05437
# [63]	validation_0-mae:239.65164
# [64]	validation_0-mae:232.30238
# [65]	validation_0-mae:224.09224
# [66]	validation_0-mae:218.19000
# [67]	validation_0-mae:216.39031
# [68]	validation_0-mae:208.88217
# [69]	validation_0-mae:204.35242
# [70]	validation_0-mae:199.12293
# [71]	validation_0-mae:191.97467
# [72]	validation_0-mae:186.37891
# [73]	validation_0-mae:182.62242
# [74]	validation_0-mae:180.94035
# [75]	validation_0-mae:175.46243
# [76]	validation_0-mae:171.21683
# [77]	validation_0-mae:167.04601
# [78]	validation_0-mae:165.41431
# [79]	validation_0-mae:161.14298
# [80]	validation_0-mae:160.23552
# [81]	validation_0-mae:154.80490
# [82]	validation_0-mae:149.29753
# [83]	validation_0-mae:147.19743
# [84]	validation_0-mae:142.24850
# [85]	validation_0-mae:140.21394
# [86]	validation_0-mae:138.48263
# [87]	validation_0-mae:137.13818
# [88]	validation_0-mae:134.68584
# [89]	validation_0-mae:131.58116
# [90]	validation_0-mae:127.51997
# [91]	validation_0-mae:123.53629
# [92]	validation_0-mae:119.79032
# [93]	validation_0-mae:115.72237
# [94]	validation_0-mae:113.38678
# [95]	validation_0-mae:110.32748
# [96]	validation_0-mae:109.42367
# [97]	validation_0-mae:107.91857
# [98]	validation_0-mae:105.56712
# [99]	validation_0-mae:103.85175
# [100]	validation_0-mae:101.18243
# [101]	validation_0-mae:98.13197
# [102]	validation_0-mae:96.79961
# [103]	validation_0-mae:95.19044
# [104]	validation_0-mae:94.89269
# [105]	validation_0-mae:92.20292
# [106]	validation_0-mae:89.76172
# [107]	validation_0-mae:87.75586
# [108]	validation_0-mae:87.05862
# [109]	validation_0-mae:84.90385
# [110]	validation_0-mae:83.39469
# [111]	validation_0-mae:81.78163
# [112]	validation_0-mae:81.56805
# [113]	validation_0-mae:79.56848
# [114]	validation_0-mae:79.04100
# [115]	validation_0-mae:77.52554
# [116]	validation_0-mae:75.98807
# [117]	validation_0-mae:75.54011
# [118]	validation_0-mae:74.26769
# [119]	validation_0-mae:72.89999
# [120]	validation_0-mae:70.76129
# [121]	validation_0-mae:69.74229
# [122]	validation_0-mae:68.65103
# [123]	validation_0-mae:67.75587
# [124]	validation_0-mae:67.53557
# [125]	validation_0-mae:65.38443
# [126]	validation_0-mae:64.93438
# [127]	validation_0-mae:63.89360
# [128]	validation_0-mae:63.03965
# [129]	validation_0-mae:62.93413
# [130]	validation_0-mae:61.34528
# [131]	validation_0-mae:59.88154
# [132]	validation_0-mae:58.52077
# [133]	validation_0-mae:57.16924
# [134]	validation_0-mae:56.34188
# [135]	validation_0-mae:54.97564
# [136]	validation_0-mae:54.17725
# [137]	validation_0-mae:53.64877
# [138]	validation_0-mae:53.02842
# [139]	validation_0-mae:51.92442
# [140]	validation_0-mae:50.75349
# [141]	validation_0-mae:50.45706
# [142]	validation_0-mae:49.43539
# [143]	validation_0-mae:48.50373
# [144]	validation_0-mae:47.89946
# [145]	validation_0-mae:47.21726
# [146]	validation_0-mae:46.94206
# [147]	validation_0-mae:46.23615
# [148]	validation_0-mae:45.63544
# [149]	validation_0-mae:45.50695
# [150]	validation_0-mae:44.43251
# [151]	validation_0-mae:43.61322
# [152]	validation_0-mae:43.05238
# [153]	validation_0-mae:42.25088
# [154]	validation_0-mae:41.54911
# [155]	validation_0-mae:40.48750
# [156]	validation_0-mae:40.05947
# [157]	validation_0-mae:39.71864
# [158]	validation_0-mae:39.62247
# [159]	validation_0-mae:38.61690
# [160]	validation_0-mae:38.16083
# [161]	validation_0-mae:37.43312
# [162]	validation_0-mae:36.86746
# [163]	validation_0-mae:36.29481
# [164]	validation_0-mae:35.72312
# [165]	validation_0-mae:35.35456
# [166]	validation_0-mae:35.02667
# [167]	validation_0-mae:34.58262
# [168]	validation_0-mae:34.27184
# [169]	validation_0-mae:33.86079
# [170]	validation_0-mae:33.25220
# [171]	validation_0-mae:33.03062
# [172]	validation_0-mae:32.77848
# [173]	validation_0-mae:32.21671
# [174]	validation_0-mae:31.54984
# [175]	validation_0-mae:31.35608
# [176]	validation_0-mae:30.80139
# [177]	validation_0-mae:30.55559
# [178]	validation_0-mae:30.13776
# [179]	validation_0-mae:29.84286
# [180]	validation_0-mae:29.65007
# [181]	validation_0-mae:29.36545
# [182]	validation_0-mae:28.84025
# [183]	validation_0-mae:28.49395
# [184]	validation_0-mae:27.98048
# [185]	validation_0-mae:27.61885
# [186]	validation_0-mae:27.47069
# [187]	validation_0-mae:27.07168
# [188]	validation_0-mae:26.80878
# [189]	validation_0-mae:26.66631
# [190]	validation_0-mae:26.34994
# [191]	validation_0-mae:25.90496
# [192]	validation_0-mae:25.53279
# [193]	validation_0-mae:25.24785
# [194]	validation_0-mae:24.91950
# [195]	validation_0-mae:24.62337
# [196]	validation_0-mae:24.19909
# [197]	validation_0-mae:23.86591
# [198]	validation_0-mae:23.51507
# [199]	validation_0-mae:23.30251
# [200]	validation_0-mae:23.19385
# [201]	validation_0-mae:23.07323
# [202]	validation_0-mae:22.83315
# [203]	validation_0-mae:22.55539
# [204]	validation_0-mae:22.27053
# [205]	validation_0-mae:22.10650
# [206]	validation_0-mae:22.00383
# [207]	validation_0-mae:21.72780
# [208]	validation_0-mae:21.40621
# [209]	validation_0-mae:21.09727
# [210]	validation_0-mae:20.84846
# [211]	validation_0-mae:20.74248
# [212]	validation_0-mae:20.45602
# [213]	validation_0-mae:20.27651
# [214]	validation_0-mae:20.07717
# [215]	validation_0-mae:19.68634
# [216]	validation_0-mae:19.49591
# [217]	validation_0-mae:19.38941
# [218]	validation_0-mae:19.30238
# [219]	validation_0-mae:18.98266
# [220]	validation_0-mae:18.75983
# [221]	validation_0-mae:18.52624
# [222]	validation_0-mae:18.27131
# [223]	validation_0-mae:18.07824
# [224]	validation_0-mae:17.78126
# [225]	validation_0-mae:17.60523
# [226]	validation_0-mae:17.45448
# [227]	validation_0-mae:17.15966
# [228]	validation_0-mae:16.89700
# [229]	validation_0-mae:16.65904
# [230]	validation_0-mae:16.50330
# [231]	validation_0-mae:16.43695
# [232]	validation_0-mae:16.27850
# [233]	validation_0-mae:16.12361
# [234]	validation_0-mae:16.08150
# [235]	validation_0-mae:15.78171
# [236]	validation_0-mae:15.60903
# [237]	validation_0-mae:15.54023
# [238]	validation_0-mae:15.39905
# [239]	validation_0-mae:15.27581
# [240]	validation_0-mae:15.21816
# [241]	validation_0-mae:15.08578
# [242]	validation_0-mae:14.88629
# [243]	validation_0-mae:14.64770
# [244]	validation_0-mae:14.46070
# [245]	validation_0-mae:14.31570
# [246]	validation_0-mae:14.20733
# [247]	validation_0-mae:14.15311
# [248]	validation_0-mae:14.09971
# [249]	validation_0-mae:14.00482
# [250]	validation_0-mae:13.96259
# [251]	validation_0-mae:13.71791
# [252]	validation_0-mae:13.57493
# [253]	validation_0-mae:13.42744
# [254]	validation_0-mae:13.20932
# [255]	validation_0-mae:13.07146
# [256]	validation_0-mae:12.97266
# [257]	validation_0-mae:12.79022
# [258]	validation_0-mae:12.64683
# [259]	validation_0-mae:12.50437
# [260]	validation_0-mae:12.38420
# [261]	validation_0-mae:12.23732
# [262]	validation_0-mae:12.13806
# [263]	validation_0-mae:11.99552
# [264]	validation_0-mae:11.81486
# [265]	validation_0-mae:11.74267
# [266]	validation_0-mae:11.65172
# [267]	validation_0-mae:11.61152
# [268]	validation_0-mae:11.47190
# [269]	validation_0-mae:11.31644
# [270]	validation_0-mae:11.27784
# [271]	validation_0-mae:11.19031
# [272]	validation_0-mae:11.10664
# [273]	validation_0-mae:11.00347
# [274]	validation_0-mae:10.96989
# [275]	validation_0-mae:10.80800
# [276]	validation_0-mae:10.72323
# [277]	validation_0-mae:10.61402
# [278]	validation_0-mae:10.51093
# [279]	validation_0-mae:10.36818
# [280]	validation_0-mae:10.22883
# [281]	validation_0-mae:10.12576
# [282]	validation_0-mae:10.03939
# [283]	validation_0-mae:9.88780
# [284]	validation_0-mae:9.80932
# [285]	validation_0-mae:9.68415
# [286]	validation_0-mae:9.50090
# [287]	validation_0-mae:9.43342
# [288]	validation_0-mae:9.36130
# [289]	validation_0-mae:9.29063
# [290]	validation_0-mae:9.17217
# [291]	validation_0-mae:9.09272
# [292]	validation_0-mae:8.97551
# [293]	validation_0-mae:8.89018
# [294]	validation_0-mae:8.82330
# [295]	validation_0-mae:8.77021
# [296]	validation_0-mae:8.73749
# [297]	validation_0-mae:8.64123
# [298]	validation_0-mae:8.57161
# [299]	validation_0-mae:8.48561
# [300]	validation_0-mae:8.41052
# [301]	validation_0-mae:8.28421
# [302]	validation_0-mae:8.20180
# [303]	validation_0-mae:8.14589
# [304]	validation_0-mae:8.06022
# [305]	validation_0-mae:7.94756
# [306]	validation_0-mae:7.88651
# [307]	validation_0-mae:7.85239
# [308]	validation_0-mae:7.77745
# [309]	validation_0-mae:7.72818
# [310]	validation_0-mae:7.63549
# [311]	validation_0-mae:7.62579
# [312]	validation_0-mae:7.59997
# [313]	validation_0-mae:7.44784
# [314]	validation_0-mae:7.34687
# [315]	validation_0-mae:7.24790
# [316]	validation_0-mae:7.16460
# [317]	validation_0-mae:7.05652
# [318]	validation_0-mae:6.97312
# [319]	validation_0-mae:6.88642
# [320]	validation_0-mae:6.79286
# [321]	validation_0-mae:6.69626
# [322]	validation_0-mae:6.63194
# [323]	validation_0-mae:6.55227
# [324]	validation_0-mae:6.47937
# [325]	validation_0-mae:6.42429
# [326]	validation_0-mae:6.35806
# [327]	validation_0-mae:6.28586
# [328]	validation_0-mae:6.21380
# [329]	validation_0-mae:6.15259
# [330]	validation_0-mae:6.11176
# [331]	validation_0-mae:6.04417
# [332]	validation_0-mae:5.97380
# [333]	validation_0-mae:5.91057
# [334]	validation_0-mae:5.83733
# [335]	validation_0-mae:5.78381
# [336]	validation_0-mae:5.73402
# [337]	validation_0-mae:5.68074
# [338]	validation_0-mae:5.62855
# [339]	validation_0-mae:5.59217
# [340]	validation_0-mae:5.52500
# [341]	validation_0-mae:5.50375
# [342]	validation_0-mae:5.47329
# [343]	validation_0-mae:5.41957
# [344]	validation_0-mae:5.36082
# [345]	validation_0-mae:5.32241
# [346]	validation_0-mae:5.30012
# [347]	validation_0-mae:5.25001
# [348]	validation_0-mae:5.20727
# [349]	validation_0-mae:5.16349
# [350]	validation_0-mae:5.11358
# [351]	validation_0-mae:5.05670
# [352]	validation_0-mae:5.00403
# [353]	validation_0-mae:4.98454
# [354]	validation_0-mae:4.94297
# [355]	validation_0-mae:4.89784
# [356]	validation_0-mae:4.84940
# [357]	validation_0-mae:4.80068
# [358]	validation_0-mae:4.76790
# [359]	validation_0-mae:4.74465
# [360]	validation_0-mae:4.70309
# [361]	validation_0-mae:4.65912
# [362]	validation_0-mae:4.61810
# [363]	validation_0-mae:4.60125
# [364]	validation_0-mae:4.54461
# [365]	validation_0-mae:4.50905
# [366]	validation_0-mae:4.45359
# [367]	validation_0-mae:4.41615
# [368]	validation_0-mae:4.36353
# [369]	validation_0-mae:4.32301
# [370]	validation_0-mae:4.27431
# [371]	validation_0-mae:4.23184
# [372]	validation_0-mae:4.19010
# [373]	validation_0-mae:4.14412
# [374]	validation_0-mae:4.11081
# [375]	validation_0-mae:4.07491
# [376]	validation_0-mae:4.05198
# [377]	validation_0-mae:4.01483
# [378]	validation_0-mae:3.97017
# [379]	validation_0-mae:3.92737
# [380]	validation_0-mae:3.89084
# [381]	validation_0-mae:3.85065
# [382]	validation_0-mae:3.81808
# [383]	validation_0-mae:3.81451
# [384]	validation_0-mae:3.79064
# [385]	validation_0-mae:3.77960
# [386]	validation_0-mae:3.74955
# [387]	validation_0-mae:3.72844
# [388]	validation_0-mae:3.71519
# [389]	validation_0-mae:3.70329
# [390]	validation_0-mae:3.67828
# [391]	validation_0-mae:3.66174
# [392]	validation_0-mae:3.64619
# [393]	validation_0-mae:3.61963
# [394]	validation_0-mae:3.58971
# [395]	validation_0-mae:3.53529
# [396]	validation_0-mae:3.50212
# [397]	validation_0-mae:3.46954
# [398]	validation_0-mae:3.44569
# [399]	validation_0-mae:3.41031
# [400]	validation_0-mae:3.38094
# [401]	validation_0-mae:3.36076
# [402]	validation_0-mae:3.35261
# [403]	validation_0-mae:3.33809
# [404]	validation_0-mae:3.31149
# [405]	validation_0-mae:3.29413
# [406]	validation_0-mae:3.26859
# [407]	validation_0-mae:3.24780
# [408]	validation_0-mae:3.20884
# [409]	validation_0-mae:3.17577
# [410]	validation_0-mae:3.12695
# [411]	validation_0-mae:3.10549
# [412]	validation_0-mae:3.07828
# [413]	validation_0-mae:3.06125
# [414]	validation_0-mae:3.04811
# [415]	validation_0-mae:3.01732
# [416]	validation_0-mae:2.99983
# [417]	validation_0-mae:2.96913
# [418]	validation_0-mae:2.93637
# [419]	validation_0-mae:2.91188
# [420]	validation_0-mae:2.87898
# [421]	validation_0-mae:2.85157
# [422]	validation_0-mae:2.82219
# [423]	validation_0-mae:2.81178
# [424]	validation_0-mae:2.79174
# [425]	validation_0-mae:2.76567
# [426]	validation_0-mae:2.73491
# [427]	validation_0-mae:2.71317
# [428]	validation_0-mae:2.69012
# [429]	validation_0-mae:2.66928
# [430]	validation_0-mae:2.65530
# [431]	validation_0-mae:2.64346
# [432]	validation_0-mae:2.63624
# [433]	validation_0-mae:2.61102
# [434]	validation_0-mae:2.58942
# [435]	validation_0-mae:2.56012
# [436]	validation_0-mae:2.53893
# [437]	validation_0-mae:2.50801
# [438]	validation_0-mae:2.48385
# [439]	validation_0-mae:2.45774
# [440]	validation_0-mae:2.44117
# [441]	validation_0-mae:2.41928
# [442]	validation_0-mae:2.39303
# [443]	validation_0-mae:2.36768
# [444]	validation_0-mae:2.34702
# [445]	validation_0-mae:2.33406
# [446]	validation_0-mae:2.31059
# [447]	validation_0-mae:2.29027
# [448]	validation_0-mae:2.28385
# [449]	validation_0-mae:2.26299
# [450]	validation_0-mae:2.24391
# [451]	validation_0-mae:2.23429
# [452]	validation_0-mae:2.22513
# [453]	validation_0-mae:2.20761
# [454]	validation_0-mae:2.19003
# [455]	validation_0-mae:2.16728
# [456]	validation_0-mae:2.14724
# [457]	validation_0-mae:2.13703
# [458]	validation_0-mae:2.12477
# [459]	validation_0-mae:2.10782
# [460]	validation_0-mae:2.08883
# [461]	validation_0-mae:2.06890
# [462]	validation_0-mae:2.04725
# [463]	validation_0-mae:2.02784
# [464]	validation_0-mae:2.00930
# [465]	validation_0-mae:1.99833
# [466]	validation_0-mae:1.98698
# [467]	validation_0-mae:1.97223
# [468]	validation_0-mae:1.95778
# [469]	validation_0-mae:1.93424
# [470]	validation_0-mae:1.91495
# [471]	validation_0-mae:1.91067
# [472]	validation_0-mae:1.89552
# [473]	validation_0-mae:1.87860
# [474]	validation_0-mae:1.85974
# [475]	validation_0-mae:1.84437
# [476]	validation_0-mae:1.82831
# [477]	validation_0-mae:1.81334
# [478]	validation_0-mae:1.79621
# [479]	validation_0-mae:1.78844
# [480]	validation_0-mae:1.78519
# [481]	validation_0-mae:1.77820
# [482]	validation_0-mae:1.76140
# [483]	validation_0-mae:1.74663
# [484]	validation_0-mae:1.73812
# [485]	validation_0-mae:1.72700
# [486]	validation_0-mae:1.71706
# [487]	validation_0-mae:1.70283
# [488]	validation_0-mae:1.68971
# [489]	validation_0-mae:1.67431
# [490]	validation_0-mae:1.66018
# [491]	validation_0-mae:1.65516
# [492]	validation_0-mae:1.64549
# [493]	validation_0-mae:1.63948
# [494]	validation_0-mae:1.63032
# [495]	validation_0-mae:1.61607
# [496]	validation_0-mae:1.60377
# [497]	validation_0-mae:1.58807
# [498]	validation_0-mae:1.57554
# [499]	validation_0-mae:1.56872
# [500]	validation_0-mae:1.55513
# [501]	validation_0-mae:1.54280
# [502]	validation_0-mae:1.53350
# [503]	validation_0-mae:1.51904
# [504]	validation_0-mae:1.50512
# [505]	validation_0-mae:1.49494
# [506]	validation_0-mae:1.48109
# [507]	validation_0-mae:1.47927
# [508]	validation_0-mae:1.47250
# [509]	validation_0-mae:1.46586
# [510]	validation_0-mae:1.46256
# [511]	validation_0-mae:1.45701
# [512]	validation_0-mae:1.45031
# [513]	validation_0-mae:1.43897
# [514]	validation_0-mae:1.42287
# [515]	validation_0-mae:1.41248
# [516]	validation_0-mae:1.40684
# [517]	validation_0-mae:1.39922
# [518]	validation_0-mae:1.39793
# [519]	validation_0-mae:1.39066
# [520]	validation_0-mae:1.38377
# [521]	validation_0-mae:1.37241
# [522]	validation_0-mae:1.35618
# [523]	validation_0-mae:1.34170
# [524]	validation_0-mae:1.32998
# [525]	validation_0-mae:1.31993
# [526]	validation_0-mae:1.30896
# [527]	validation_0-mae:1.29704
# [528]	validation_0-mae:1.28791
# [529]	validation_0-mae:1.27646
# [530]	validation_0-mae:1.26662
# [531]	validation_0-mae:1.25487
# [532]	validation_0-mae:1.24533
# [533]	validation_0-mae:1.23743
# [534]	validation_0-mae:1.22915
# [535]	validation_0-mae:1.22435
# [536]	validation_0-mae:1.21655
# [537]	validation_0-mae:1.20745
# [538]	validation_0-mae:1.20446
# [539]	validation_0-mae:1.19451
# [540]	validation_0-mae:1.18593
# [541]	validation_0-mae:1.17564
# [542]	validation_0-mae:1.16775
# [543]	validation_0-mae:1.15665
# [544]	validation_0-mae:1.14729
# [545]	validation_0-mae:1.13900
# [546]	validation_0-mae:1.12976
# [547]	validation_0-mae:1.12147
# [548]	validation_0-mae:1.11043
# [549]	validation_0-mae:1.10392
# [550]	validation_0-mae:1.09847
# [551]	validation_0-mae:1.09170
# [552]	validation_0-mae:1.08172
# [553]	validation_0-mae:1.07638
# [554]	validation_0-mae:1.07015
# [555]	validation_0-mae:1.06363
# [556]	validation_0-mae:1.05757
# [557]	validation_0-mae:1.05240
# [558]	validation_0-mae:1.04895
# [559]	validation_0-mae:1.04458
# [560]	validation_0-mae:1.03919
# [561]	validation_0-mae:1.03196
# [562]	validation_0-mae:1.02329
# [563]	validation_0-mae:1.01873
# [564]	validation_0-mae:1.01128
# [565]	validation_0-mae:1.00397
# [566]	validation_0-mae:1.00008
# [567]	validation_0-mae:0.99745
# [568]	validation_0-mae:0.99298
# [569]	validation_0-mae:0.98728
# [570]	validation_0-mae:0.97694
# [571]	validation_0-mae:0.96776
# [572]	validation_0-mae:0.95872
# [573]	validation_0-mae:0.95062
# [574]	validation_0-mae:0.94858
# [575]	validation_0-mae:0.94493
# [576]	validation_0-mae:0.93711
# [577]	validation_0-mae:0.92982
# [578]	validation_0-mae:0.92347
# [579]	validation_0-mae:0.92207
# [580]	validation_0-mae:0.91845
# [581]	validation_0-mae:0.91672
# [582]	validation_0-mae:0.91188
# [583]	validation_0-mae:0.90733
# [584]	validation_0-mae:0.89988
# [585]	validation_0-mae:0.88940
# [586]	validation_0-mae:0.88075
# [587]	validation_0-mae:0.87334
# [588]	validation_0-mae:0.87028
# [589]	validation_0-mae:0.86689
# [590]	validation_0-mae:0.86069
# [591]	validation_0-mae:0.85902
# [592]	validation_0-mae:0.85289
# [593]	validation_0-mae:0.84975
# [594]	validation_0-mae:0.84350
# [595]	validation_0-mae:0.83558
# [596]	validation_0-mae:0.83026
# [597]	validation_0-mae:0.82396
# [598]	validation_0-mae:0.82125
# [599]	validation_0-mae:0.81491
# [600]	validation_0-mae:0.80679
# [601]	validation_0-mae:0.80282
# [602]	validation_0-mae:0.79914
# [603]	validation_0-mae:0.79075
# [604]	validation_0-mae:0.78566
# [605]	validation_0-mae:0.77758
# [606]	validation_0-mae:0.77253
# [607]	validation_0-mae:0.76662
# [608]	validation_0-mae:0.76281
# [609]	validation_0-mae:0.75906
# [610]	validation_0-mae:0.75565
# [611]	validation_0-mae:0.75041
# [612]	validation_0-mae:0.74426
# [613]	validation_0-mae:0.73824
# [614]	validation_0-mae:0.73184
# [615]	validation_0-mae:0.72848
# [616]	validation_0-mae:0.72585
# [617]	validation_0-mae:0.71640
# [618]	validation_0-mae:0.71431
# [619]	validation_0-mae:0.71299
# [620]	validation_0-mae:0.70664
# [621]	validation_0-mae:0.70156
# [622]	validation_0-mae:0.69777
# [623]	validation_0-mae:0.69040
# [624]	validation_0-mae:0.68617
# [625]	validation_0-mae:0.68063
# [626]	validation_0-mae:0.67557
# [627]	validation_0-mae:0.67047
# [628]	validation_0-mae:0.66610
# [629]	validation_0-mae:0.66146
# [630]	validation_0-mae:0.65731
# [631]	validation_0-mae:0.65313
# [632]	validation_0-mae:0.64771
# [633]	validation_0-mae:0.64354
# [634]	validation_0-mae:0.63836
# [635]	validation_0-mae:0.63437
# [636]	validation_0-mae:0.62825
# [637]	validation_0-mae:0.62606
# [638]	validation_0-mae:0.62325
# [639]	validation_0-mae:0.61977
# [640]	validation_0-mae:0.61625
# [641]	validation_0-mae:0.61322
# [642]	validation_0-mae:0.60984
# [643]	validation_0-mae:0.60619
# [644]	validation_0-mae:0.60477
# [645]	validation_0-mae:0.60167
# [646]	validation_0-mae:0.59898
# [647]	validation_0-mae:0.59267
# [648]	validation_0-mae:0.59026
# [649]	validation_0-mae:0.58652
# [650]	validation_0-mae:0.58095
# [651]	validation_0-mae:0.57782
# [652]	validation_0-mae:0.57352
# [653]	validation_0-mae:0.57267
# [654]	validation_0-mae:0.57096
# [655]	validation_0-mae:0.56832
# [656]	validation_0-mae:0.56590
# [657]	validation_0-mae:0.56261
# [658]	validation_0-mae:0.55938
# [659]	validation_0-mae:0.55452
# [660]	validation_0-mae:0.55054
# [661]	validation_0-mae:0.54783
# [662]	validation_0-mae:0.54458
# [663]	validation_0-mae:0.54100
# [664]	validation_0-mae:0.53544
# [665]	validation_0-mae:0.53273
# [666]	validation_0-mae:0.52656
# [667]	validation_0-mae:0.52003
# [668]	validation_0-mae:0.51507
# [669]	validation_0-mae:0.51188
# [670]	validation_0-mae:0.50839
# [671]	validation_0-mae:0.50422
# [672]	validation_0-mae:0.50169
# [673]	validation_0-mae:0.49881
# [674]	validation_0-mae:0.49571
# [675]	validation_0-mae:0.49075
# [676]	validation_0-mae:0.48740
# [677]	validation_0-mae:0.48563
# [678]	validation_0-mae:0.48347
# [679]	validation_0-mae:0.48094
# [680]	validation_0-mae:0.47824
# [681]	validation_0-mae:0.47510
# [682]	validation_0-mae:0.47315
# [683]	validation_0-mae:0.47114
# [684]	validation_0-mae:0.46629
# [685]	validation_0-mae:0.46565
# [686]	validation_0-mae:0.46355
# [687]	validation_0-mae:0.46212
# [688]	validation_0-mae:0.45818
# [689]	validation_0-mae:0.45556
# [690]	validation_0-mae:0.45347
# [691]	validation_0-mae:0.45167
# [692]	validation_0-mae:0.44824
# [693]	validation_0-mae:0.44649
# [694]	validation_0-mae:0.44401
# [695]	validation_0-mae:0.44196
# [696]	validation_0-mae:0.43887
# [697]	validation_0-mae:0.43559
# [698]	validation_0-mae:0.43377
# [699]	validation_0-mae:0.43156
# [700]	validation_0-mae:0.42924
# [701]	validation_0-mae:0.42644
# [702]	validation_0-mae:0.42448
# [703]	validation_0-mae:0.42322
# [704]	validation_0-mae:0.42109
# [705]	validation_0-mae:0.41934
# [706]	validation_0-mae:0.41779
# [707]	validation_0-mae:0.41673
# [708]	validation_0-mae:0.41519
# [709]	validation_0-mae:0.41085
# [710]	validation_0-mae:0.40994
# [711]	validation_0-mae:0.40764
# [712]	validation_0-mae:0.40425
# [713]	validation_0-mae:0.40090
# [714]	validation_0-mae:0.39802
# [715]	validation_0-mae:0.39671
# [716]	validation_0-mae:0.39391
# [717]	validation_0-mae:0.39219
# [718]	validation_0-mae:0.39041
# [719]	validation_0-mae:0.38963
# [720]	validation_0-mae:0.38702
# [721]	validation_0-mae:0.38423
# [722]	validation_0-mae:0.38294
# [723]	validation_0-mae:0.38013
# [724]	validation_0-mae:0.37607
# [725]	validation_0-mae:0.37248
# [726]	validation_0-mae:0.37065
# [727]	validation_0-mae:0.36669
# [728]	validation_0-mae:0.36408
# [729]	validation_0-mae:0.36089
# [730]	validation_0-mae:0.35911
# [731]	validation_0-mae:0.35631
# [732]	validation_0-mae:0.35391
# [733]	validation_0-mae:0.35324
# [734]	validation_0-mae:0.35040
# [735]	validation_0-mae:0.34794
# [736]	validation_0-mae:0.34496
# [737]	validation_0-mae:0.34341
# [738]	validation_0-mae:0.34049
# [739]	validation_0-mae:0.33837
# [740]	validation_0-mae:0.33610
# [741]	validation_0-mae:0.33463
# [742]	validation_0-mae:0.33247
# [743]	validation_0-mae:0.33063
# [744]	validation_0-mae:0.32914
# [745]	validation_0-mae:0.32665
# [746]	validation_0-mae:0.32541
# [747]	validation_0-mae:0.32357
# [748]	validation_0-mae:0.32314
# [749]	validation_0-mae:0.32179
# [750]	validation_0-mae:0.32067
# [751]	validation_0-mae:0.31979
# [752]	validation_0-mae:0.31938
# [753]	validation_0-mae:0.31739
# [754]	validation_0-mae:0.31595
# [755]	validation_0-mae:0.31349
# [756]	validation_0-mae:0.31207
# [757]	validation_0-mae:0.30983
# [758]	validation_0-mae:0.30656
# [759]	validation_0-mae:0.30519
# [760]	validation_0-mae:0.30384
# [761]	validation_0-mae:0.30087
# [762]	validation_0-mae:0.30007
# [763]	validation_0-mae:0.29895
# [764]	validation_0-mae:0.29785
# [765]	validation_0-mae:0.29647
# [766]	validation_0-mae:0.29537
# [767]	validation_0-mae:0.29296
# [768]	validation_0-mae:0.29253
# [769]	validation_0-mae:0.29057
# [770]	validation_0-mae:0.28854
# [771]	validation_0-mae:0.28518
# [772]	validation_0-mae:0.28311
# [773]	validation_0-mae:0.28029
# [774]	validation_0-mae:0.27846
# [775]	validation_0-mae:0.27614
# [776]	validation_0-mae:0.27362
# [777]	validation_0-mae:0.27162
# [778]	validation_0-mae:0.27028
# [779]	validation_0-mae:0.26824
# [780]	validation_0-mae:0.26648
# [781]	validation_0-mae:0.26552
# [782]	validation_0-mae:0.26396
# [783]	validation_0-mae:0.26249
# [784]	validation_0-mae:0.26066
# [785]	validation_0-mae:0.25937
# [786]	validation_0-mae:0.25784
# [787]	validation_0-mae:0.25668
# [788]	validation_0-mae:0.25510
# [789]	validation_0-mae:0.25362
# [790]	validation_0-mae:0.25236
# [791]	validation_0-mae:0.25124
# [792]	validation_0-mae:0.25006
# [793]	validation_0-mae:0.24966
# [794]	validation_0-mae:0.24696
# [795]	validation_0-mae:0.24596
# [796]	validation_0-mae:0.24477
# [797]	validation_0-mae:0.24279
# [798]	validation_0-mae:0.24186
# [799]	validation_0-mae:0.24086
# [800]	validation_0-mae:0.23961
# [801]	validation_0-mae:0.23876
# [802]	validation_0-mae:0.23712
# [803]	validation_0-mae:0.23620
# [804]	validation_0-mae:0.23558
# [805]	validation_0-mae:0.23524
# [806]	validation_0-mae:0.23444
# [807]	validation_0-mae:0.23349
# [808]	validation_0-mae:0.23264
# [809]	validation_0-mae:0.23172
# [810]	validation_0-mae:0.23094
# [811]	validation_0-mae:0.23011
# [812]	validation_0-mae:0.22982
# [813]	validation_0-mae:0.22906
# [814]	validation_0-mae:0.22803
# [815]	validation_0-mae:0.22590
# [816]	validation_0-mae:0.22364
# [817]	validation_0-mae:0.22197
# [818]	validation_0-mae:0.22026
# [819]	validation_0-mae:0.21836
# [820]	validation_0-mae:0.21731
# [821]	validation_0-mae:0.21595
# [822]	validation_0-mae:0.21520
# [823]	validation_0-mae:0.21495
# [824]	validation_0-mae:0.21415
# [825]	validation_0-mae:0.21254
# [826]	validation_0-mae:0.21180
# [827]	validation_0-mae:0.21082
# [828]	validation_0-mae:0.20857
# [829]	validation_0-mae:0.20658
# [830]	validation_0-mae:0.20571
# [831]	validation_0-mae:0.20413
# [832]	validation_0-mae:0.20255
# [833]	validation_0-mae:0.20197
# [834]	validation_0-mae:0.20123
# [835]	validation_0-mae:0.20056
# [836]	validation_0-mae:0.19894
# [837]	validation_0-mae:0.19739
# [838]	validation_0-mae:0.19565
# [839]	validation_0-mae:0.19418
# [840]	validation_0-mae:0.19296
# [841]	validation_0-mae:0.19192
# [842]	validation_0-mae:0.19122
# [843]	validation_0-mae:0.19058
# [844]	validation_0-mae:0.18991
# [845]	validation_0-mae:0.18918
# [846]	validation_0-mae:0.18882
# [847]	validation_0-mae:0.18751
# [848]	validation_0-mae:0.18624
# [849]	validation_0-mae:0.18505
# [850]	validation_0-mae:0.18438
# [851]	validation_0-mae:0.18310
# [852]	validation_0-mae:0.18128
# [853]	validation_0-mae:0.17963
# [854]	validation_0-mae:0.17894
# [855]	validation_0-mae:0.17783
# [856]	validation_0-mae:0.17691
# [857]	validation_0-mae:0.17629
# [858]	validation_0-mae:0.17567
# [859]	validation_0-mae:0.17498
# [860]	validation_0-mae:0.17383
# [861]	validation_0-mae:0.17267
# [862]	validation_0-mae:0.17051
# [863]	validation_0-mae:0.16914
# [864]	validation_0-mae:0.16795
# [865]	validation_0-mae:0.16688
# [866]	validation_0-mae:0.16589
# [867]	validation_0-mae:0.16517
# [868]	validation_0-mae:0.16401
# [869]	validation_0-mae:0.16352
# [870]	validation_0-mae:0.16238
# [871]	validation_0-mae:0.16193
# [872]	validation_0-mae:0.16118
# [873]	validation_0-mae:0.16031
# [874]	validation_0-mae:0.16007
# [875]	validation_0-mae:0.15951
# [876]	validation_0-mae:0.15901
# [877]	validation_0-mae:0.15876
# [878]	validation_0-mae:0.15822
# [879]	validation_0-mae:0.15788
# [880]	validation_0-mae:0.15742
# [881]	validation_0-mae:0.15587
# [882]	validation_0-mae:0.15464
# [883]	validation_0-mae:0.15451
# [884]	validation_0-mae:0.15372
# [885]	validation_0-mae:0.15283
# [886]	validation_0-mae:0.15106
# [887]	validation_0-mae:0.15040
# [888]	validation_0-mae:0.14931
# [889]	validation_0-mae:0.14833
# [890]	validation_0-mae:0.14796
# [891]	validation_0-mae:0.14695
# [892]	validation_0-mae:0.14586
# [893]	validation_0-mae:0.14510
# [894]	validation_0-mae:0.14435
# [895]	validation_0-mae:0.14359
# [896]	validation_0-mae:0.14264
# [897]	validation_0-mae:0.14108
# [898]	validation_0-mae:0.14059
# [899]	validation_0-mae:0.13989
# [900]	validation_0-mae:0.13911
# [901]	validation_0-mae:0.13878
# [902]	validation_0-mae:0.13846
# [903]	validation_0-mae:0.13804
# [904]	validation_0-mae:0.13769
# [905]	validation_0-mae:0.13725
# [906]	validation_0-mae:0.13648
# [907]	validation_0-mae:0.13547
# [908]	validation_0-mae:0.13498
# [909]	validation_0-mae:0.13415
# [910]	validation_0-mae:0.13342
# [911]	validation_0-mae:0.13275
# [912]	validation_0-mae:0.13196
# [913]	validation_0-mae:0.13105
# [914]	validation_0-mae:0.13025
# [915]	validation_0-mae:0.12927
# [916]	validation_0-mae:0.12820
# [917]	validation_0-mae:0.12736
# [918]	validation_0-mae:0.12671
# [919]	validation_0-mae:0.12631
# [920]	validation_0-mae:0.12610
# [921]	validation_0-mae:0.12578
# [922]	validation_0-mae:0.12560
# [923]	validation_0-mae:0.12510
# [924]	validation_0-mae:0.12455
# [925]	validation_0-mae:0.12391
# [926]	validation_0-mae:0.12231
# [927]	validation_0-mae:0.12165
# [928]	validation_0-mae:0.12101
# [929]	validation_0-mae:0.12063
# [930]	validation_0-mae:0.12049
# [931]	validation_0-mae:0.12009
# [932]	validation_0-mae:0.11901
# [933]	validation_0-mae:0.11867
# [934]	validation_0-mae:0.11789
# [935]	validation_0-mae:0.11734
# [936]	validation_0-mae:0.11585
# [937]	validation_0-mae:0.11536
# [938]	validation_0-mae:0.11526
# [939]	validation_0-mae:0.11477
# [940]	validation_0-mae:0.11450
# [941]	validation_0-mae:0.11420
# [942]	validation_0-mae:0.11398
# [943]	validation_0-mae:0.11293
# [944]	validation_0-mae:0.11221
# [945]	validation_0-mae:0.11167
# [946]	validation_0-mae:0.11089
# [947]	validation_0-mae:0.11031
# [948]	validation_0-mae:0.10995
# [949]	validation_0-mae:0.10943
# [950]	validation_0-mae:0.10866
# [951]	validation_0-mae:0.10805
# [952]	validation_0-mae:0.10724
# [953]	validation_0-mae:0.10650
# [954]	validation_0-mae:0.10580
# [955]	validation_0-mae:0.10510
# [956]	validation_0-mae:0.10426
# [957]	validation_0-mae:0.10357
# [958]	validation_0-mae:0.10250
# [959]	validation_0-mae:0.10171
# [960]	validation_0-mae:0.10084
# [961]	validation_0-mae:0.10022
# [962]	validation_0-mae:0.09931
# [963]	validation_0-mae:0.09883
# [964]	validation_0-mae:0.09818
# [965]	validation_0-mae:0.09779
# [966]	validation_0-mae:0.09746
# [967]	validation_0-mae:0.09673
# [968]	validation_0-mae:0.09617
# [969]	validation_0-mae:0.09577
# [970]	validation_0-mae:0.09546
# [971]	validation_0-mae:0.09535
# [972]	validation_0-mae:0.09487
# [973]	validation_0-mae:0.09423
# [974]	validation_0-mae:0.09359
# [975]	validation_0-mae:0.09319
# [976]	validation_0-mae:0.09278
# [977]	validation_0-mae:0.09197
# [978]	validation_0-mae:0.09136
# [979]	validation_0-mae:0.09109
# [980]	validation_0-mae:0.09069
# [981]	validation_0-mae:0.09012
# [982]	validation_0-mae:0.08941
# [983]	validation_0-mae:0.08887
# [984]	validation_0-mae:0.08824
# [985]	validation_0-mae:0.08782
# [986]	validation_0-mae:0.08720
# [987]	validation_0-mae:0.08658
# [988]	validation_0-mae:0.08601
# [989]	validation_0-mae:0.08554
# [990]	validation_0-mae:0.08513
# [991]	validation_0-mae:0.08494
# [992]	validation_0-mae:0.08484
# [993]	validation_0-mae:0.08475
# [994]	validation_0-mae:0.08429
# [995]	validation_0-mae:0.08364
# [996]	validation_0-mae:0.08312
# [997]	validation_0-mae:0.08269
# [998]	validation_0-mae:0.08220
# [999]	validation_0-mae:0.08175

# %%
# Let's visually see the results
plt.scatter(x=train.index, y=train['PJME_MW'], label='Training Data', color='black')
plt.scatter(x=test.index, y=test['PJME_MW'], label='Test Actuals', color='red')
plt.plot(XGB_prediction_no_lag, label='XGB No Lag', color='orange')

# Plot Labels, Legends etc
plt.xlabel("Timestamp")
plt.ylabel("MWh")
plt.legend(loc='best')
plt.title('XGBoost Model (Daily) - Results')

# For clarify, let's limit to only 2015 onwards
plt.xlim(datetime(2006, 3, 1),datetime(2006, 3, 30))

plt.show()

# %% [markdown]
# Again let's see feature importance - this time by gain, not weight (as model trained on gain)

# %%
import xgboost as xgb

xgb.plot_importance(model, max_num_features=10, importance_type='gain') # gain is how much each feature contributed to 'improvement' of tree

plt.show()

# %% [markdown]
# Overall, quite good results! Now let's have a look at the residuals/errors.
#
# First let's look at the distribution of the errors - remember, the ideal state is the errors are centred around zero (meaning the model does n't particularly over or under forecast in a biased way):

# %%
# First construct the residuals - basically the errors
xgboost_errors = XGB_prediction_no_lag.copy()
xgboost_errors['PJME_MW_ACTUAL'] = test.copy()
xgboost_errors['error'] = xgboost_errors['PJME_MW'] - xgboost_errors['PJME_MW_ACTUAL']

# %%
xgboost_errors.head()
# Out:
#                           PJME_MW  PJME_MW_ACTUAL        error
# Datetime
# 2006-03-20 00:00:00  30861.998047         28525.0  2336.998047
# 2006-03-20 01:00:00  28099.582031         27166.0   933.582031
# 2006-03-20 02:00:00  27325.769531         26551.0   774.769531
# 2006-03-20 03:00:00  27358.751953         26506.0   852.751953
# 2006-03-20 04:00:00  27407.755859         26768.0   639.755859

# %%
# Let's visually see the errors via scatterplot
plt.scatter(xgboost_errors.index, xgboost_errors['error'], label='Residual/Errors')

# Plot Labels, Legends etc
plt.title('XGBoost - Residual/Errors Distribution')
plt.xlabel("Timestamp")
plt.ylabel("MWh")
plt.legend(loc='best')

plt.show()

# %%
# Plot Histogram with Kernel Density Estimation (KDE)
sns.distplot(xgboost_errors['error'], kde=True);

# Plot Labels, Legends etc
plt.title('XGBoost - Residual/Errors Distribution')
# Out:
# Text(0.5, 1.0, 'XGBoost - Residual/Errors Distribution')

# %% [markdown]
# So looking quite good - you can see some forecasts were pretty off (particularly for spikes), but overall, it seems the model treats overs and under equal.

# %% [markdown]
# Next let's look at the autocorrelation of the errors

# %%
from statsmodels.graphics.tsaplots import plot_acf

# Plot the acf function
plot_acf(xgboost_errors['error'],lags=100) #alpha 1 suppresses CI

plt.title('XGBoost - Residual/Errors Autocorrelation')
plt.show()

# %% [markdown]
# ## So most of the points are within the shaded blue (ie confidence interval), indicating there's no statistically significant autocorrelation going on. This is good, as if there was autocorrelation with our errors, it means there's some autocorrelation our model is failing to capture.

# %% [markdown]
# # LASSO (L1) Regression
#
# LASSO regression incorporate regularisation and feature selection into its algorithm. Regularisation is a technique used in regression algorithms to avoid overfitting. For LASSO, this means it will penalise the 'irrelevant' features by effectively by 'zeroing' out those features (by multiplying it with a 0 coefficient).
#
# The main hyperparameter to tune is the penalty factor (i.e. lambda or alpha). A factor of 0 means no penalisation occurs, and it effectively just does an Ordinary-Least-Squares (OLS) regression.
#
# Since we've already set up all the train-test split (as well as feature engineering) in the prior XGBoost model, we can just re-use it.
#
# However, like the decision tree-based XGBoost, linear regression is sensitive to scale. Therefore, we also need to scale the data.

# %%
data_used.head()
# Out:
#                      PJME_MW
# Datetime
# 2006-02-24 00:00:00  30862.0
# 2006-02-24 01:00:00  28921.0
# 2006-02-24 02:00:00  27917.0
# 2006-02-24 03:00:00  27621.0
# 2006-02-24 04:00:00  27727.0

# %%
# So because we need the lag data, we need to preprocess then do the split
data_preprocessed = data_used.copy()

# Create train test dataset using XGBoost preprocessing (365 days top 720 days lag)
feature, label = preprocess_xgb_data(data_preprocessed, lag_start=575, lag_end=720)

# We will aim for a 12 month forecast horizon (ie predict the last 365 days in the dataset)
train_feature = feature[:576]
train_label = label[:576]

test_feature = feature[576:]
test_label = label[576:]

train_feature = train_feature.fillna(0)
test_feature = test_feature.fillna(0)

train_feature.drop(columns=['date_epoch']) #Don't need timestamp
test_feature.drop(columns=['date_epoch']) #Don't need timestamp

# Scale dataset
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

train_feature_scaled = scaler.fit_transform(train_feature)
test_feature_scaled = scaler.transform(test_feature)

# %% [markdown]
# Next we'll train the model using sklearn's time series split cross validation method.
#
# In this case, we'll create a 5-fold split.

# %%
# Create Time Series k-fold cross validation
from sklearn.model_selection import TimeSeriesSplit
tscv = TimeSeriesSplit(n_splits=100) # in this case 5-fold

#Train and predict using LASSO
from sklearn.linear_model import LassoCV

model = LassoCV(
    alphas=[0.0001, 0.0003, 0.0006, 0.001, 0.003, 0.006, 0.01, 0.03, 0.06, 0.1,0.3, 0.6, 1]    
    ,max_iter=20000 # 1000 iterations
    ,random_state=42
    ,cv=tscv
    ,verbose=True
)
model.fit(
    train_feature_scaled
    ,train_label
)
LASSO_prediction = xtest.copy()
LASSO_prediction['PJME_MW Prediction'] = model.predict(test_feature_scaled)
LASSO_prediction = LASSO_prediction[['Datetime', 'PJME_MW Prediction']].set_index('Datetime')
LASSO_prediction = LASSO_prediction.rename(columns={'PJME_MW Prediction': 'PJME_MW'})

LASSO_prediction
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    6.4s finished
#                           PJME_MW
# Datetime
# 2006-03-20 00:00:00  26376.843089
# 2006-03-20 01:00:00  26710.820267
# 2006-03-20 02:00:00  27026.959822
# 2006-03-20 03:00:00  27332.971233
# 2006-03-20 04:00:00  27619.532579
# ...                           ...
# 2006-03-25 20:00:00  28582.798939
# 2006-03-25 21:00:00  28926.249206
# 2006-03-25 22:00:00  29298.446268
# 2006-03-25 23:00:00  29671.600715
# 2006-03-26 00:00:00  21864.637984
#
# [145 rows x 1 columns]

# %% [markdown]
# Now let's plot the results

# %%
# Let's visually see the results
plt.scatter(x=train.index, y=train['PJME_MW'], label='Training Data', color='black')
plt.scatter(x=test.index, y=test['PJME_MW'], label='Test Actuals', color='red')
plt.plot(LASSO_prediction, label='LASSO', color='orange')

# Plot Labels, Legends etc
plt.xlabel("Timestamp")
plt.ylabel("MWh")
plt.legend(loc='best')
plt.title('LASSO Model (Daily) - Results')
plt.tight_layout()
plt.grid(True)


# For clarify, let's limit to only 2015 onwards
plt.xlim(datetime(2006, 3, 1),datetime(2006, 3, 30))         

plt.show()

# %% [markdown]
# Next let's see feature importance by way of coefficients - we'll only get Top 10.
#
# Remember, LASSO will 'zero-out' irrelevant features, so in this case, these are the Top 10 features that LASSO considers are most important.

# %%
# Plot feature importance by way of coefficients    

# Create DataFrame
coefs = pd.DataFrame(model.coef_, train_feature.columns)
coefs.columns = ["coef"]

# Only grab the Top 10 Coefficients
coefs["abs"] = coefs.coef.apply(np.abs)
coefs = coefs.sort_values(by="abs", ascending=False).head(10)
coefs = coefs.drop(["abs"], axis=1)

# Plot
coefs.coef.plot(kind='bar')

# Plot title and x-axis line
plt.title("Coefficients - Feature Importance")
plt.hlines(y=0, xmin=0, xmax=len(coefs), linestyles='dashed');

# %% [markdown]
# So LASSO is producing half decent results! Now let's have a look at the residuals/errors.
#
# First let's look at the distribution of the errors - remember, the ideal state is the errors are centred around zero (meaning the model doesn't particularly over or under forecast in a biased way)

# %%
# First construct the residuals - basically the errors
lasso_errors = LASSO_prediction.copy()
lasso_errors['PJME_MW_ACTUAL'] = test.copy()
lasso_errors['error'] = lasso_errors['PJME_MW'] - lasso_errors['PJME_MW_ACTUAL']

# %%
# Plot Histogram with Kernel Density Estimation (KDE)
sns.distplot(lasso_errors['error'], kde=True)

# Plot Labels, Legends etc
plt.title('LASSO - Residual/Errors Distribution')

plt.show()

# %%
# Plot the acf function
plot_acf(lasso_errors['error'],lags=143) #alpha 1 suppresses CI

plt.title('LASSO - Residual/Errors Autocorrelation')
plt.show()

# %% [markdown]
# # SARIMA
#
# The conventional ARIMA model assumes that the historical data are useful to predict the value at the next time step. In this case, this is somewhat true, as the ACF plot before showed past value is somewhat correlated with today's value.
#
# ARIMA basically integrates two naive forecasting techniques together:
#
# 1. **Autoregression** - Uses one or more past values to forecast the future. The number of values used is known as the 'order' (e.g. order 2 means yesterday and day before's value is used)
#
# 2. **Integrating** - the part that reduces seasonality. How many degrees of differencing is done to reduce seasonality is the 'order'.
#
# 3. **Moving Average** - Uses the Moving Average of the historical data to adjust the forecasted values. This has a 'smoothing' effect on the past data, as it uses the moving average rather than the actual values of the past. The number of days in the moving average window is the 'order'.
#
# SARIMA then adds a '**seasonality**' flavour to the ARIMA model - it factors in trends and seasonality, as explained above.
#
# The main hyperparameters are SARIMAX(p,d,q)(P,D,Q,m):
# 1. autoregression order (p)
# 2. Integrating order (d)
# 3. moving average window (q)
# 4. Seasonal autoregressive order (P)
# 5. Seasonal difference order (D)
# 6. Seasonal moving average order (Q)
# 7. number of time steps for a single seasonal period (m)
#
# The X is the exogenous (external) variables to the model - they are optional and for this model we won't use them.

# %% [markdown]
# Like Holtwinters, the training and testing data was split between 2002 to 2017 and 2017 to 2018.
#
# The results were as follows:

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tools.eval_measures import meanabs

# Equivalent to R's Auto ARIMA to get the optimal parameters
#import pmdarima as pm
#model = pm.auto_arima(htrain, seasonal=True, stationary=True, stepwise=True, trace=True, suppress_warnings=True)

# First we split it up between train and test
htrain = train['PJME_MW'] # SARIMAX takes series, not DF
htest = test['PJME_MW'] # SARIMAX takes series, not DF

# Next define hyperparameters. Default is AR model (1,0,0)(0,0,0,0)
p = 1 # AR order
d = 0 # I degree
q = 1 # MA window
P = 0 # AR seasonal order
D = 1 # I seasonal order
Q = 2 # MA seasonal order
m = 6 # Seasonality period length

model = SARIMAX(
    htrain,
    order=(p, d, q),
    seasonal_order=(P, D, Q, m)
    ,enforce_stationarity=False
    ,enforce_invertibility=False
).fit(
    maxiter=50 # Default is 50
)

results = model.get_prediction(start=htest.index.min(), end=htest.index.max(), dynamic=False)
SARIMA_prediction_CI = results.conf_int(alpha=(1-0.8)) # 80% CI
SARIMA_prediction = results.predicted_mean
SARIMA_prediction = SARIMA_prediction.to_frame().rename(columns={0: 'PJME_MW'})

# Evaluate it's performance using Mean Absolute Error (MAE)
print("Finished training and predicting. MAE SARIMA: {:.20f}. AIC: {}. Parameters: p,d,q,P,D,Q,m: ".format(meanabs(htest, SARIMA_prediction['PJME_MW']), model.aic), p,d,q,P,D,Q,m)
# Out:
# Finished training and predicting. MAE SARIMA: 3644.15506025305285220384. AIC: 9142.974387242888. Parameters: p,d,q,P,D,Q,m:  1 0 1 0 1 2 6
# C:\Users\thewr\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
# Let's see what the model did
model.plot_diagnostics(figsize=(15, 12))
plt.show()

# %% [markdown]
# Importantly, the model should have the residuals uncorrelated and normally distributed (ie the mean should be zero). That is the, the centre point of the residuals should be zero and the distribution plot (KDE) should also be centred on 0.

# %% [markdown]
# Let's evaluate the results and visualise it.

# %%
# Evaluate it's performance using Mean Absolute Error (MAE)
from statsmodels.tools.eval_measures import meanabs

print("MAE SARIMA: {:.20f}".format(meanabs(htest, SARIMA_prediction['PJME_MW'])))
# Out:
# MAE SARIMA: 3644.15506025305285220384

# %%
# Let's visually see the results
plt.scatter(x=train.index, y=train['PJME_MW'], label='Training Data', color='black')
plt.scatter(x=test.index, y=test['PJME_MW'], label='Test Actuals', color='red')
plt.plot(SARIMA_prediction['PJME_MW'], label='SARIMA', color='orange')

# Plot Confidence Interval
plt.fill_between(
    SARIMA_prediction.index,
    SARIMA_prediction_CI['lower PJME_MW'],
    SARIMA_prediction_CI['upper PJME_MW'],
    color='skyblue',
    alpha=0.7, # 70% transparency
    label='80% CI'
)

# Plot Labels, Legends etc
plt.xlabel("Timestamp")
plt.ylabel("MWh")
plt.legend(loc='best')
plt.title('SARIMA Model (Daily) - Results')

# For clarify, let's limit to only 2017 onwards
plt.xlim(datetime(2006, 3, 1),datetime(2006, 3, 31))

plt.show()

# %% [markdown]
# So you can see that despite some tuning, the results are not particularly good. The confidence interval is very big, indicating the model has is not 'confident' in the prediction either.

# %% [markdown]
# # Prophet
#
# Lastly, we will use Facebook Prophet - an open-source library that is also a generalised additive model (ie final result is made up of multiple components added together).
#
# ## It's all about probabilities!
#
# Unlike regular Generalised Linear Models, Facebook Prophet's uses a Bayesian curve fitting approach. The concept of Bayesian theorem is, at high level, trying to determine the probability of related events given knowledge/assumptions you already know (ie 'priors').
#
# This is basically fancy talk for saying it focuses on finding a bunch of possible parameters and the probability of each one rather than finding fixed optimal values for the model. How certain (or uncertain) the model is about each possible parameter is known as the 'uncertainty interval' - the less data the model sees, the bigger the interval is.
#
# The sources of uncertainty that Prophet's Bayesian approach aims to address are:
#
# * Uncertainty of the predicted value
# * Uncertainty of the trend and trend changes
# * Uncertainty of additional noise
#
# ## Trends, 'Changepoints' and Seasonality
#
# Prophet is different to SARIMA and HoltWinters, as it essentially decomposes time series differently by:
#
# **Data = Trend +/x Seasonality +/x Holidays +/x Noise**
#
# In Prophet, trend represents non-periodic changes while seasonality represents periodic changes. Where it differs from other statistic models like SARIMA and Holtwinters is Prophet factors in the uncertainty of trends changing.
#
# Interestingly, Prophet fits a curve to each component independently (ie fits a regression for each component with time as independent variable). That is:
#
# Trend - fits piece-wise linear/log curve
# Seasonality - uses fourier series
# Holidays - uses constant/fixed values
# Prophet reacts to changes in trends by 'changepoints' - that is sudden and abrupt changes in the trend. An example, is the release of a new electric car that will impact sale of petrol cars.
#
# How 'reactive'/flexible Prophet is to changepoints will impact how much fluctation the model will do. For example, when the changepoint scale is to very high, it becomes very sensitive and any small changes to the trend will be picked up. Consequently, the sensitive model may detect spikes that won't amount to anything, while an insensitive model may miss spikes altogether.
#
# The uncertainty of the predictions is determined by the number of changepoints and the flexibility of the changepoint allowed. In other words, if there were many changes in the past, there's likely going to be many changes in the future. Prophet gets the uncertainty by randomly sampling changepoints and seeing what happened before and after.
#
# Furthermore, Prophet factors in seasonality by considering both its length (ie seasonal period) and its frequency (ie its 'fourier order').For example, if something keeps happening every week on Monday, the period is 7 days and its frequency is 52 times a year.
#
# There's also a function for Prophet to consider additional factors (e.g. holidays), but for the purposes of this forecast we won't use it.

# %% [markdown]
# ## Training
# Prophet works quite well out of the box, so I just stuck with the default hyperparameters.
#
# The results can be seen below, with the black dots representing historical points and the blue line representing the prediction:

# %%
from fbprophet import Prophet

ftrain = train.reset_index().rename(columns={'Datetime':'ds', 'PJME_MW': 'y'}) # Prophet takes ds and y as column names only

model = Prophet(
    n_changepoints=25 # Default is 25
    ,changepoint_prior_scale=0.05 # Default is 0.05
    ,seasonality_mode='additive'
    ,interval_width=0.8 # CI - default is 0.8 or 80%
)
model.fit(ftrain)

# Create the future dataframe with date range that will be used to test accuracy
future_df = test.reset_index()['Datetime'].to_frame().rename(columns={"Datetime":'ds'})

# Predict the future
forecast = model.predict(future_df)
PROPHET_prediction = forecast.set_index('ds')[['yhat', 'yhat_lower', 'yhat_upper']][cutoff:]
PROPHET_prediction = PROPHET_prediction.rename(columns={'yhat': 'PJME_MW'})

print("Finished training and predicting")
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# Finished training and predicting

# %%
model.plot(forecast)

plt.show()

# %% [markdown]
# Let's zoom into 2017 onwards and visualise it (with the consistent graph format as above):

# %%
# Let's visually see the results
plt.scatter(x=train.index, y=train['PJME_MW'], label='Training Data', color='black')
plt.scatter(x=test.index, y=test['PJME_MW'], label='Test Actuals', color='red')
plt.plot(PROPHET_prediction['PJME_MW'], label='Prophet', color='orange')

# Plot Confidence Interval
plt.fill_between(
    PROPHET_prediction.index,
    PROPHET_prediction['yhat_lower'],
    PROPHET_prediction['yhat_upper'],
    color='skyblue',
    alpha=0.7, # 70% transparency
    label='80% CI'
)

# Plot Labels, Legends etc
plt.xlabel("Timestamp")
plt.ylabel("MWh")
plt.legend(loc='best')
plt.title('Prophet Model (Daily) - Results')

# For clarify, let's limit to only 2017 onwards
plt.xlim(datetime(2006, 3, 1),datetime(2006, 3, 30))

plt.show()

# %% [markdown]
# You can see the 80% confidence interval (in light blue), indicating the model is confident that 80% of the actual data will land in that predicted range.

# %% [markdown]
# Like Holtwinters, let's see the components of the model:

# %%
model.plot_components(forecast)

plt.show()

# %% [markdown]
# You can easily see seasonality and trends - there's a clear downward trend and seasonality every year (more electricity is used in winter)

# %% [markdown]
# Now let's evaluate the residuals and see whether the model is biased in any way. First we'll look at the distribution of the errors:

# %%
# First construct the residuals - basically the errors
prophet_errors = PROPHET_prediction.copy()
prophet_errors['PJME_MW_ACTUAL'] = test['PJME_MW']
prophet_errors['error'] = prophet_errors['PJME_MW'] - prophet_errors['PJME_MW_ACTUAL']

# %%
# Let's visually see the errors via scatterplot
plt.scatter(prophet_errors.index, prophet_errors['error'], label='Residual/Errors')

# Plot Labels, Legends etc
plt.title('Prophet - Residual/Errors Distribution')
plt.xlabel("Timestamp")
plt.ylabel("MWh")
plt.legend(loc='best')

plt.show()

# %%
# Plot Histogram with Kernel Density Estimation (KDE)
sns.distplot(prophet_errors['error'], kde=True);

# Plot Labels, Legends etc
plt.title('Prophet - Residual/Errors Distribution')
# Out:
# Text(0.5, 1.0, 'Prophet - Residual/Errors Distribution')

# %%
from statsmodels.graphics.tsaplots import plot_acf

# Plot the acf function
plot_acf(xgboost_errors['error'],lags=143) #alpha 1 suppresses CI

plt.title('XGBoost - Residual/Errors Autocorrelation')
plt.show()

# %% [markdown]
# Again, you can see that the errors seem to be distributed around zero and there's no statistically significant autocorrelation going on. This indicates that the model isn't biased and not leaning torwards under or over forecasting.
#
# However, you can see that the model does seem to miss under forecast a bit more, particularly for spikes.
#
# Let's have a closer look at the biggest under forecasts:

# %%
# Let's get the top 10 over forecasts (i.e. where the error is the highest negative number)
top_10_errors = prophet_errors.sort_values('error', ascending=True)[['PJME_MW_ACTUAL', 'PJME_MW', 'error']].head(10)

plt.scatter(top_10_errors.index, top_10_errors['PJME_MW'], label='Predicted MW')
plt.scatter(top_10_errors.index, top_10_errors['PJME_MW_ACTUAL'], label='Actual MW')

# Labels, Titles, etc.
plt.title('Prophet - Top 10 Errors')
plt.xlabel("Timestamp")
plt.ylabel("MWh")
plt.legend(loc='best')

# %%
top_10_errors.head(10)

# %% [markdown]
# The most incorrect days were July and January, the peak of summer and winter respectively. Makes sense!
#
# You get the biggest peaks in these periods due to weather.

# %% [markdown]
# # Bringing it all together - the final results
#
# Finally, Let's bring the models together and see which one did the best:

# %%
#print("MAE Baseline: {:.2f}".format(meanabs(test['PJME_MW'], baseline_prediction['PJME_MW'])))
print("MAE HoltWinters: {:.2f}".format(meanabs(test['PJME_MW'], HWES_prediction['PJME_MW'])))
print("MAE XGBoost: {:.2f}".format(mean_absolute_error(test_label, XGB_prediction_no_lag['PJME_MW'])))
print("MAE LASSO: {:.2f}".format(mean_absolute_error(test_label, LASSO_prediction['PJME_MW'])))
print("MAE SARIMA: {:.2f}".format(meanabs(test['PJME_MW'], SARIMA_prediction['PJME_MW'])))
print("MAE Prophet: {:.2f}".format(meanabs(test['PJME_MW'], PROPHET_prediction['PJME_MW'])))
# Out:
# MAE HoltWinters: 15174.04
# MAE XGBoost: 732.62
# MAE LASSO: 4294.53
# MAE SARIMA: 3644.16
# MAE Prophet: 2590.35

# %% [markdown]
# Now let's also look at Mean Absolute Percentage Error (MAPE)
#
# Unlike MAE, MAPE has issues in its calculations, namely when the actual value is 0 (can't divide by zero) and negative values can't go beyond -100%.
#
# Regardless, MAPE is a good 'sense-check' to see which model is proportionally better.

# %%
def MAPE(y_true, y_pred): 
    '''Function to calculate MAPE'''
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
#print("MAE Baseline: {:.2f}%".format(MAPE(test['PJME_MW'], baseline_prediction['PJME_MW'])))
print("MAE HoltWinters: {:.2f}%".format(MAPE(test['PJME_MW'], HWES_prediction['PJME_MW'])))
print("MAE XGBoost: {:.2f}%".format(MAPE(test['PJME_MW'], XGB_prediction_no_lag['PJME_MW'])))
print("MAE LASSO: {:.2f}%".format(MAPE(test['PJME_MW'], LASSO_prediction['PJME_MW'])))
print("MAE SARIMA: {:.2f}%".format(MAPE(test['PJME_MW'], SARIMA_prediction['PJME_MW'])))
print("MAE Prophet: {:.2f}%".format(MAPE(test['PJME_MW'], PROPHET_prediction['PJME_MW'])))
# Out:
# MAE HoltWinters: 47.62%
# MAE XGBoost: 2.38%
# MAE LASSO: 12.99%
# MAE SARIMA: 10.97%
# MAE Prophet: 8.41%

# %%
def plot_model_result(ax, prediction, model_name, color):
    '''
    Plot model results.
    
    prediction : DataFrame
    model_name : str
    
    return ax
    '''
    # Training and Test Actuals
    ax.scatter(x=train.index, y=train['PJME_MW'], label='Training Data', color='black')
    ax.scatter(x=test.index, y=test['PJME_MW'], label='Test Actuals', color='red')

    # Model Results
    ax.plot(prediction['PJME_MW'], label=model_name, color=color, alpha=0.7)
    
    # For clarify, let's limit to only August 2016 onwards
    ax.set_xlim(datetime(2006, 3, 1),datetime(2006, 3, 30))

    # Set Y Axis
    ax.set_ylim(10000, 40000)
    
    # Set Axis labels
    ax.set_ylabel("MWh")
    ax.legend(loc='best')
    ax.set_title(
        "{}: MAPE: {:.2f}% | MAE: {:.2f}".format(
            model_name,MAPE(test["PJME_MW"], prediction["PJME_MW"]),
            mean_absolute_error(test["PJME_MW"], prediction["PJME_MW"])
            )
        , fontsize=40
    )

    return ax

# %%
fig, ax = plt.subplots(6,1, figsize=(30,40))

# Plot Labels, Legends etc
plt.xlabel("Timestamp")

#ax[0] = plot_model_result(ax[0], baseline_prediction, model_name='Baseline (Naive)', color='midnightblue')
ax[1] = plot_model_result(ax[1], XGB_prediction_no_lag, model_name='XGBoost', color='deepskyblue')
ax[2] = plot_model_result(ax[2], PROPHET_prediction, model_name='Prophet', color='steelblue')
ax[3] = plot_model_result(ax[3], LASSO_prediction, model_name='LASSO', color='royalblue')
ax[4] = plot_model_result(ax[4], HWES_prediction, model_name='Holtwinters', color='lightsteelblue')
ax[5] = plot_model_result(ax[5], SARIMA_prediction, model_name='SARIMA', color='dodgerblue')

plt.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# The lower the error the better/more accurate the model is, so therefore in this case, the winner is LASSO! However, Prophet and XGBoost still comes a pretty close second!
#
# You can see that there was a lot of noise in this dataset and while there's high seasonality, more conventional statistical approaches, such as Holtwinters and SARIMA weren't able to get through all that noise.
#
# Interestingly, all the forecasting models beat the baseline, except Holtwinters and SARIMA. This does at least demonstrate that we are still better off using these models than just doing naive forecasting.
#
# Hopefully that gives you a bit of a flavour to time series forecasting and some of the unique aspects of it!
